# %% [markdown]
# <a href="https://colab.research.google.com/github/reemchaaban/game_system/blob/main/data-processing/game_rec_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preparation

# %%
pip install steamspypi
# Out:
# Requirement already satisfied: steamspypi in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from steamspypi) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (2025.1.31)

# %%
import steamspypi
import time
import csv
import json
import random
import numpy as np

# %% [markdown]
# # Part 1: Create games library

# %% [markdown]
# ## SteamSpy API

# %% [markdown]
# ### Fetch top 1000 most owned games

# %%
data_request = dict()
data_request['request'] = 'all'
data_request['page'] = '0'

all_games = steamspypi.download(data_request)

# %%
len(all_games)
# Out:
# 1000

# %% [markdown]
# ### Take subset

# %%
all_games = dict(list(all_games.items())[:200])
len(all_games)
# Out:
# 200

# %%
print(next(iter(all_games.items())))
# Out:
# ('570', {'appid': 570, 'name': 'Dota 2', 'developer': 'Valve', 'publisher': 'Valve', 'score_rank': '', 'positive': 2009078, 'negative': 455042, 'userscore': 0, 'owners': '200,000,000 .. 500,000,000', 'average_forever': 41715, 'average_2weeks': 1376, 'median_forever': 889, 'median_2weeks': 708, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 460383})

# %% [markdown]
# ### Drop "Wallpaper Engine" outlier game

# %%
for key, value in list(all_games.items()):
    if value['name'] == "Wallpaper Engine":
        del all_games[key]
        break

# %% [markdown]
# ### For each game in subset, fetch more details

# %%
all_games_detailed = {}

# %%
data_request = dict()
data_request['request'] = 'appdetails'

# %%
for game_id, game_data in all_games.items():
  data_request["appid"] = game_id
  data = steamspypi.download(data_request)

  tag_list = list(data.get("tags", {}).keys())

  all_games_detailed[str(game_id)] = {
      "name": data.get("name", ""),
      "rating_ratio": round(data.get("positive", 1) / data.get("negative", 1), 3),
      "price": data.get("price", "0"),
      "genre": [g.strip() for g in data.get("genre", "").split(",")],
      "tags": tag_list
  }

  time.sleep(1)

# %%
all_games_detailed
# Out:
# {'570': {'name': 'Dota 2',
#   'rating_ratio': 4.415,
#   'price': '0',
#   'genre': ['Action', 'Strategy', 'Free To Play'],
#   'tags': ['Free to Play',
#    'MOBA',
#    'Multiplayer',
#    'Strategy',
#    'e-sports',
#    'Team-Based',
#    'Competitive',
#    'Action',
#    'Online Co-Op',
#    'PvP',
#    'Difficult',
#    'Co-op',
#    'RTS',
#    'RPG',
#    'Tower Defense',
#    'Fantasy',
#    'Character Customization',
#    'Replay Value',
#    'Action RPG',
#    'Simulation']},
#  '730': {'name': 'Counter-Strike: Global Offensive',
#   'rating_ratio': 6.571,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['FPS',
#    'Shooter',
#    'Multiplayer',
#    'Competitive',
#    'Action',
#    'Team-Based',
#    'e-sports',
#    'Tactical',
#    'First-Person',
#    'PvP',
#    'Online Co-Op',
#    'Co-op',
#    'Strategy',
#    'Military',
#    'War',
#    'Difficult',
#    'Trading',
#    'Realistic',
#    'Fast-Paced',
#    'Moddable']},
#  '578080': {'name': 'PUBG: BATTLEGROUNDS',
#   'rating_ratio': 1.458,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer', 'Free To Play'],
#   'tags': ['Survival',
#    'Shooter',
#    'Battle Royale',
#    'Multiplayer',
#    'FPS',
#    'PvP',
#    'Third-Person Shooter',
#    'Action',
#    'Online Co-Op',
#    'Tactical',
#    'Co-op',
#    'First-Person',
#    'Strategy',
#    'Early Access',
#    'Competitive',
#    'Third Person',
#    'Team-Based',
#    'Difficult',
#    'Simulation',
#    'Stealth']},
#  '1623730': {'name': 'Palworld',
#   'rating_ratio': 16.051,
#   'price': '2999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Early Access'],
#   'tags': ['Open World',
#    'Survival',
#    'Multiplayer',
#    'Creature Collector',
#    'Open World Survival Craft',
#    'Crafting',
#    'Co-op',
#    'Adventure',
#    'Sandbox',
#    'Third-Person Shooter',
#    'Automation',
#    'Action',
#    'RPG',
#    'Early Access',
#    'Anime',
#    'PvE',
#    '3D',
#    'Indie',
#    'Looter Shooter',
#    'Hack and Slash']},
#  '1172470': {'name': 'Apex Legends',
#   'rating_ratio': 2.045,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Battle Royale',
#    'Multiplayer',
#    'FPS',
#    'Shooter',
#    'First-Person',
#    'PvP',
#    'Action',
#    'Hero Shooter',
#    'Team-Based',
#    'Tactical',
#    'Sci-fi',
#    'Survival',
#    'Loot',
#    'Co-op',
#    'Character Customization',
#    'Funny',
#    'Lore-Rich',
#    'Cyberpunk',
#    'Cinematic']},
#  '1063730': {'name': 'New World: Aeternum',
#   'rating_ratio': 2.188,
#   'price': '7999',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer', 'RPG'],
#   'tags': ['Open World',
#    'Massively Multiplayer',
#    'MMORPG',
#    'RPG',
#    'Adventure',
#    'Action',
#    'PvP',
#    'PvE',
#    'Multiplayer',
#    'Fantasy',
#    'Character Customization',
#    'Walking Simulator',
#    'Crafting',
#    'Third Person',
#    'Co-op',
#    'Open World Survival Craft',
#    'Sandbox',
#    'Violent',
#    'Sexual Content',
#    'Singleplayer']},
#  '2358720': {'name': 'Black Myth: Wukong',
#   'rating_ratio': 29.039,
#   'price': '5999',
#   'genre': ['Action', 'Adventure', 'RPG'],
#   'tags': ['Mythology',
#    'Action RPG',
#    'Action',
#    'Souls-like',
#    'RPG',
#    'Combat',
#    'Story Rich',
#    'Singleplayer',
#    'Action-Adventure',
#    'Drama',
#    'Dark Fantasy',
#    'Atmospheric',
#    'Adventure',
#    '3D',
#    'Fantasy',
#    'Hack and Slash',
#    'Third Person',
#    'Difficult',
#    'Music',
#    'Violent']},
#  '1938090': {'name': 'Call of Duty: Modern Warfare II',
#   'rating_ratio': 1.418,
#   'price': '4899',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Singleplayer',
#    'Action',
#    'Military',
#    'First-Person',
#    'War',
#    'Modern',
#    'Tactical',
#    'Violent',
#    'Co-op',
#    'Realistic',
#    'Story Rich',
#    'Atmospheric',
#    'Mature',
#    'Online Co-Op',
#    'Gore',
#    'Third-Person Shooter',
#    'Third Person']},
#  '271590': {'name': 'Grand Theft Auto V Legacy',
#   'rating_ratio': 6.901,
#   'price': '0',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Action',
#    'Multiplayer',
#    'Crime',
#    'Automobile Sim',
#    'Third Person',
#    'First-Person',
#    'Mature',
#    'Shooter',
#    'Adventure',
#    'Singleplayer',
#    'Third-Person Shooter',
#    'Racing',
#    'Co-op',
#    'Sandbox',
#    'Atmospheric',
#    'Funny',
#    'Great Soundtrack',
#    'Comedy',
#    'Moddable']},
#  '550': {'name': 'Left 4 Dead 2',
#   'rating_ratio': 39.598,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Zombies',
#    'Co-op',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Online Co-Op',
#    'Action',
#    'Survival',
#    'Horror',
#    'First-Person',
#    'Gore',
#    'Team-Based',
#    'Moddable',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Adventure',
#    'Local Co-Op',
#    'Replay Value',
#    'Tactical']},
#  '553850': {'name': 'HELLDIVERS 2',
#   'rating_ratio': 3.196,
#   'price': '3999',
#   'genre': ['Action'],
#   'tags': ['Online Co-Op',
#    'PvE',
#    'Third-Person Shooter',
#    'Multiplayer',
#    'Action',
#    'Shooter',
#    'Co-op',
#    'Sci-fi',
#    'Capitalism',
#    'Space',
#    'Extraction Shooter',
#    'Third Person',
#    'Comedy',
#    'Gore',
#    'Violent',
#    'Great Soundtrack',
#    'Difficult',
#    'Psychological Horror',
#    'Singleplayer',
#    'Open World']},
#  '1599340': {'name': 'Lost Ark',
#   'rating_ratio': 2.463,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['MMORPG',
#    'Free to Play',
#    'Action RPG',
#    'Multiplayer',
#    'Hack and Slash',
#    'RPG',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Action',
#    'Sexual Content',
#    'Adventure',
#    'PvE',
#    'Fantasy',
#    'PvP',
#    'Isometric',
#    'Online Co-Op',
#    'Class-Based',
#    'Singleplayer',
#    'Violent',
#    'Gore']},
#  '304930': {'name': 'Unturned',
#   'rating_ratio': 10.407,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Casual', 'Indie', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Co-op',
#    'Sandbox',
#    'Crafting',
#    'Shooter',
#    'Adventure',
#    'Post-apocalyptic',
#    'First-Person',
#    'Singleplayer',
#    'Looter Shooter',
#    'FPS',
#    'Action',
#    'Massively Multiplayer',
#    'Indie',
#    'Atmospheric',
#    'Casual']},
#  '236390': {'name': 'War Thunder',
#   'rating_ratio': 1.751,
#   'price': '0',
#   'genre': ['Action', 'Massively Multiplayer', 'Simulation', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Simulation',
#    'Vehicular Combat',
#    'Combat',
#    'World War II',
#    'Flight',
#    'VR',
#    'War',
#    'Military',
#    'Tanks',
#    'Multiplayer',
#    'Naval Combat',
#    'Modern',
#    'Massively Multiplayer',
#    'Cold War',
#    'Realistic',
#    'Shooter',
#    'Action',
#    'Third Person',
#    'Third-Person Shooter']},
#  '1245620': {'name': 'ELDEN RING',
#   'rating_ratio': 12.998,
#   'price': '5999',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Souls-like',
#    'Open World',
#    'Dark Fantasy',
#    'RPG',
#    'Difficult',
#    'Action RPG',
#    'Third Person',
#    'Multiplayer',
#    'Fantasy',
#    'Singleplayer',
#    'Online Co-Op',
#    'Action',
#    'Co-op',
#    'Atmospheric',
#    'PvP',
#    'Great Soundtrack',
#    'Violent',
#    '3D',
#    'Character Customization',
#    'Family Friendly']},
#  '105600': {'name': 'Terraria',
#   'rating_ratio': 38.865,
#   'price': '999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Open World Survival Craft',
#    'Sandbox',
#    'Survival',
#    '2D',
#    'Multiplayer',
#    'Adventure',
#    'Pixel Graphics',
#    'Crafting',
#    'Building',
#    'Exploration',
#    'Co-op',
#    'Open World',
#    'Online Co-Op',
#    'Indie',
#    'Action',
#    'RPG',
#    'Singleplayer',
#    'Replay Value',
#    'Platformer',
#    'Atmospheric']},
#  '440': {'name': 'Team Fortress 2',
#   'rating_ratio': 8.623,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Hero Shooter',
#    'Multiplayer',
#    'FPS',
#    'Shooter',
#    'Action',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Online Co-Op',
#    'Competitive',
#    'Cartoony',
#    'Trading',
#    'Co-op',
#    'Comedy',
#    'Robots',
#    'Tactical',
#    'Cartoon',
#    'Crafting']},
#  '291550': {'name': 'Brawlhalla',
#   'rating_ratio': 4.447,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'Fighting',
#    '2D Fighter',
#    '2D Platformer',
#    'Casual',
#    'Local Multiplayer',
#    'Co-op',
#    'Platformer',
#    'Controller',
#    'Action',
#    'Online Co-Op',
#    'Fantasy',
#    'Local Co-Op',
#    '4 Player Local',
#    'Family Friendly',
#    'Cartoony',
#    'e-sports',
#    'Singleplayer',
#    'Indie']},
#  '1086940': {'name': "Baldur's Gate 3",
#   'rating_ratio': 30.665,
#   'price': '5999',
#   'genre': ['Adventure', 'RPG', 'Strategy'],
#   'tags': ['RPG',
#    'Character Customization',
#    'Choices Matter',
#    'Story Rich',
#    'Turn-Based Combat',
#    'Dungeons & Dragons',
#    'CRPG',
#    'Fantasy',
#    'Adventure',
#    'Romance',
#    'Sexual Content',
#    'Online Co-Op',
#    'Multiplayer',
#    'Strategy',
#    'Singleplayer',
#    'Co-op Campaign',
#    'Class-Based',
#    'Nudity',
#    'Dark Fantasy',
#    'Combat']},
#  '4000': {'name': "Garry's Mod",
#   'rating_ratio': 30.168,
#   'price': '999',
#   'genre': ['Casual', 'Indie', 'Simulation'],
#   'tags': ['Sandbox',
#    'Moddable',
#    'Multiplayer',
#    'Physics',
#    'Building',
#    'Casual',
#    'Funny',
#    'First-Person',
#    'Singleplayer',
#    'FPS',
#    'Simulation',
#    'Comedy',
#    'Online Co-Op',
#    'Shooter',
#    'Co-op',
#    'Action',
#    'Indie',
#    'PvP',
#    'Realistic',
#    'Exploration']},
#  '359550': {'name': "Tom Clancy's Rainbow Six Siege",
#   'rating_ratio': 5.248,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'PvP',
#    'e-sports',
#    'Multiplayer',
#    'Tactical',
#    'Shooter',
#    'Competitive',
#    'Online Co-Op',
#    'Action',
#    'Hero Shooter',
#    'Team-Based',
#    'Military',
#    'Strategy',
#    'First-Person',
#    'Co-op',
#    'War',
#    'Realistic',
#    'Destruction',
#    'Difficult',
#    '3D']},
#  '1085660': {'name': 'Destiny 2',
#   'rating_ratio': 3.925,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Open World',
#    'Multiplayer',
#    'Looter Shooter',
#    'MMORPG',
#    'FPS',
#    'Co-op',
#    'PvE',
#    'PvP',
#    'Shooter',
#    'Massively Multiplayer',
#    'Loot',
#    'First-Person',
#    'Sci-fi',
#    'Action',
#    'Adventure',
#    'Lore-Rich',
#    'Space',
#    'Competitive',
#    'Atmospheric']},
#  '252490': {'name': 'Rust',
#   'rating_ratio': 6.851,
#   'price': '3999',
#   'genre': ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG'],
#   'tags': ['Survival',
#    'Crafting',
#    'Multiplayer',
#    'Open World',
#    'Open World Survival Craft',
#    'Building',
#    'PvP',
#    'Sandbox',
#    'Adventure',
#    'First-Person',
#    'Action',
#    'Nudity',
#    'FPS',
#    'Shooter',
#    'Co-op',
#    'Online Co-Op',
#    'Indie',
#    'Post-apocalyptic',
#    'Early Access',
#    'Simulation']},
#  '346110': {'name': 'ARK: Survival Evolved',
#   'rating_ratio': 5.158,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG'],
#   'tags': ['Open World Survival Craft',
#    'Survival',
#    'Multiplayer',
#    'Open World',
#    'Dinosaurs',
#    'Crafting',
#    'Building',
#    'Adventure',
#    'Base-Building',
#    'Co-op',
#    'Action',
#    'First-Person',
#    'Sandbox',
#    'Massively Multiplayer',
#    'Singleplayer',
#    'Early Access',
#    'RPG',
#    'Dragons',
#    'Sci-fi',
#    'Indie']},
#  '892970': {'name': 'Valheim',
#   'rating_ratio': 16.792,
#   'price': '1999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Early Access'],
#   'tags': ['Open World Survival Craft',
#    'Survival',
#    'Online Co-Op',
#    'Open World',
#    'Multiplayer',
#    'Building',
#    'Crafting',
#    'Base-Building',
#    'Exploration',
#    'Co-op',
#    'Adventure',
#    'Difficult',
#    'Mythology',
#    'Sandbox',
#    'PvE',
#    'Third Person',
#    'Singleplayer',
#    'Action',
#    'Early Access',
#    'Indie']},
#  '1091500': {'name': 'Cyberpunk 2077',
#   'rating_ratio': 5.293,
#   'price': '5999',
#   'genre': ['RPG'],
#   'tags': ['Cyberpunk',
#    'Open World',
#    'Nudity',
#    'RPG',
#    'Singleplayer',
#    'Sci-fi',
#    'FPS',
#    'Futuristic',
#    'Mature',
#    'Story Rich',
#    'First-Person',
#    'Atmospheric',
#    'Exploration',
#    'Action',
#    'Violent',
#    'Great Soundtrack',
#    'Action RPG',
#    'Adventure',
#    'Character Customization',
#    'Immersive Sim']},
#  '218620': {'name': 'PAYDAY 2',
#   'rating_ratio': 8.637,
#   'price': '999',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Co-op',
#    'Action',
#    'FPS',
#    'Heist',
#    'Multiplayer',
#    'Looter Shooter',
#    'Online Co-Op',
#    'Stealth',
#    'Crime',
#    'Shooter',
#    'Team-Based',
#    'First-Person',
#    'Great Soundtrack',
#    'Gun Customization',
#    'Tactical',
#    'PvE',
#    'Strategy',
#    'Singleplayer',
#    'Funny',
#    'Simulation']},
#  '901583': {'name': 'Grand Theft Auto IV: Complete Edition',
#   'rating_ratio': 4.671,
#   'price': '0',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Action',
#    'Automobile Sim',
#    'Crime',
#    'Multiplayer',
#    'Third Person',
#    'Adventure',
#    'Singleplayer',
#    'Third-Person Shooter',
#    'Moddable',
#    'Sandbox',
#    'Shooter',
#    'Physics',
#    'Atmospheric',
#    'Classic',
#    'Funny',
#    'Dark Humor',
#    'Gore',
#    'Satire',
#    'Co-op']},
#  '238960': {'name': 'Path of Exile',
#   'rating_ratio': 8.341,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Dark Fantasy',
#    'Action RPG',
#    'Hack and Slash',
#    'Loot',
#    'MMORPG',
#    'Multiplayer',
#    'Dungeon Crawler',
#    'Isometric',
#    'Character Customization',
#    'RPG',
#    'Inventory Management',
#    'Online Co-Op',
#    'Singleplayer',
#    'Action',
#    'PvP',
#    'Horror',
#    'Massively Multiplayer',
#    'Fantasy',
#    'Adventure']},
#  '242760': {'name': 'The Forest',
#   'rating_ratio': 21.425,
#   'price': '1999',
#   'genre': ['Action', 'Adventure', 'Indie', 'Simulation'],
#   'tags': ['Open World Survival Craft',
#    'Survival',
#    'Open World',
#    'Horror',
#    'Crafting',
#    'Adventure',
#    'Building',
#    'Survival Horror',
#    'First-Person',
#    'Action',
#    'Exploration',
#    'Sandbox',
#    'Singleplayer',
#    'Atmospheric',
#    'Simulation',
#    'Gore',
#    'Realistic',
#    'Indie',
#    'Zombies',
#    'Early Access']},
#  '322330': {'name': "Don't Starve Together",
#   'rating_ratio': 20.515,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy'],
#   'tags': ['Survival',
#    'Open World Survival Craft',
#    'Multiplayer',
#    'Co-op',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Online Co-Op',
#    'Sandbox',
#    'Difficult',
#    'Indie',
#    '2D',
#    'Atmospheric',
#    'Funny',
#    'Survival Horror',
#    'Strategy',
#    'Horror',
#    'Singleplayer',
#    'Action',
#    'Rogue-like']},
#  '1203220': {'name': 'NARAKA: BLADEPOINT',
#   'rating_ratio': 2.344,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer'],
#   'tags': ['Battle Royale',
#    'Multiplayer',
#    'Martial Arts',
#    'PvP',
#    'Mature',
#    'Action',
#    'Female Protagonist',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Survival',
#    'Fighting',
#    'Third Person',
#    'Swordplay',
#    'Hack and Slash',
#    'Anime',
#    'Parkour',
#    'Adventure',
#    'Free to Play',
#    'Violent',
#    'Gore']},
#  '899770': {'name': 'Last Epoch',
#   'rating_ratio': 3.407,
#   'price': '3499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Action RPG',
#    'Loot',
#    'Hack and Slash',
#    'RPG',
#    'Multiplayer',
#    'Isometric',
#    'Action',
#    'Adventure',
#    'Co-op',
#    'Top-Down',
#    'Dungeon Crawler',
#    'Indie',
#    'Singleplayer',
#    'Fantasy',
#    'Gore',
#    'MMORPG',
#    'Character Customization',
#    'Magic',
#    'Violent',
#    'Early Access']},
#  '413150': {'name': 'Stardew Valley',
#   'rating_ratio': 62.919,
#   'price': '1499',
#   'genre': ['Indie', 'RPG', 'Simulation'],
#   'tags': ['Farming Sim',
#    'Pixel Graphics',
#    'Multiplayer',
#    'Life Sim',
#    'RPG',
#    'Relaxing',
#    'Agriculture',
#    'Simulation',
#    'Crafting',
#    'Sandbox',
#    'Indie',
#    'Building',
#    'Casual',
#    'Singleplayer',
#    'Open World',
#    '2D',
#    'Cute',
#    'Dating Sim',
#    'Great Soundtrack',
#    'Fishing']},
#  '340': {'name': 'Half-Life 2: Lost Coast',
#   'rating_ratio': 8.326,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Singleplayer',
#    'First-Person',
#    'Sci-fi',
#    'Shooter',
#    'Short',
#    'Aliens',
#    'Dystopian ',
#    'Classic',
#    'Adventure',
#    'Atmospheric',
#    'Benchmark',
#    'Futuristic',
#    'Silent Protagonist',
#    'Free to Play',
#    'Post-apocalyptic',
#    'Story Rich',
#    'Multiplayer',
#    'Great Soundtrack']},
#  '381210': {'name': 'Dead by Daylight',
#   'rating_ratio': 3.771,
#   'price': '799',
#   'genre': ['Action'],
#   'tags': ['Horror',
#    'Multiplayer',
#    'Survival Horror',
#    'Online Co-Op',
#    'Co-op',
#    'Survival',
#    'Gore',
#    'Team-Based',
#    'Blood',
#    'Stealth',
#    'Third Person',
#    'Violent',
#    'First-Person',
#    'Psychological Horror',
#    'Action',
#    'Atmospheric',
#    'Strategy',
#    'Comedy',
#    'Mature',
#    'Difficult']},
#  '945360': {'name': 'Among Us',
#   'rating_ratio': 11.271,
#   'price': '499',
#   'genre': ['Casual'],
#   'tags': ['Multiplayer',
#    'Social Deduction',
#    'Online Co-Op',
#    'Space',
#    'Survival',
#    '2D',
#    'Funny',
#    'Psychological',
#    'Party Game',
#    'Co-op',
#    'Cartoony',
#    'Local Multiplayer',
#    'Casual',
#    'Action',
#    'PvP',
#    'Sci-fi',
#    'Colorful',
#    'Top-Down',
#    'Minigames',
#    'Aliens']},
#  '1097150': {'name': 'Fall Guys: Ultimate Knockout',
#   'rating_ratio': 4.347,
#   'price': '0',
#   'genre': ['Action', 'Casual', 'Indie', 'Massively Multiplayer', 'Sports'],
#   'tags': ['Multiplayer',
#    'Party Game',
#    'Battle Royale',
#    'Family Friendly',
#    'Massively Multiplayer',
#    'Platformer',
#    'Cute',
#    'Funny',
#    'PvP',
#    '3D Platformer',
#    'Controller',
#    'Casual',
#    'Colorful',
#    'Action',
#    'Online Co-Op',
#    'Co-op',
#    'Comedy',
#    'Physics',
#    'Indie',
#    'Difficult']},
#  '292030': {'name': 'The Witcher 3: Wild Hunt',
#   'rating_ratio': 24.78,
#   'price': '3999',
#   'genre': ['RPG'],
#   'tags': ['Open World',
#    'RPG',
#    'Story Rich',
#    'Atmospheric',
#    'Mature',
#    'Fantasy',
#    'Adventure',
#    'Singleplayer',
#    'Nudity',
#    'Choices Matter',
#    'Great Soundtrack',
#    'Third Person',
#    'Medieval',
#    'Action',
#    'Multiple Endings',
#    'Action RPG',
#    'Dark Fantasy',
#    'Magic',
#    'Dark',
#    'Sandbox']},
#  '227300': {'name': 'Euro Truck Simulator 2',
#   'rating_ratio': 36.9,
#   'price': '499',
#   'genre': ['Indie', 'Simulation'],
#   'tags': ['Driving',
#    'Transportation',
#    'Simulation',
#    'Open World',
#    'Automobile Sim',
#    'Realistic',
#    'Moddable',
#    'Relaxing',
#    'Exploration',
#    'Economy',
#    'Immersive Sim',
#    'Management',
#    'Atmospheric',
#    'Multiplayer',
#    'Controller',
#    'Family Friendly',
#    'Third Person',
#    'Adventure',
#    'Casual',
#    'Indie']},
#  '444090': {'name': 'Paladins',
#   'rating_ratio': 5.654,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Massively Multiplayer',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Hero Shooter',
#    'Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'First-Person',
#    'PvP',
#    'MOBA',
#    'Online Co-Op',
#    'Fantasy',
#    'Controller',
#    'Strategy',
#    'Co-op',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Colorful',
#    'Adventure',
#    'Funny']},
#  '552990': {'name': 'World of Warships',
#   'rating_ratio': 3.378,
#   'price': '0',
#   'genre': ['Action',
#    'Massively Multiplayer',
#    'Simulation',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Naval Combat',
#    'Co-op',
#    'Action',
#    'Tactical',
#    'Online Co-Op',
#    'Multiplayer',
#    'Massively Multiplayer',
#    'World War II',
#    'PvP',
#    'Naval',
#    'War',
#    'Simulation',
#    'Team-Based',
#    'Military',
#    'PvE',
#    'Shooter',
#    'Historical',
#    'Realistic',
#    'Third-Person Shooter']},
#  '438100': {'name': 'VRChat',
#   'rating_ratio': 3.092,
#   'price': '0',
#   'genre': ['Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'Simulation',
#    'Sports',
#    'Free To Play',
#    'Early Access'],
#   'tags': ['VR',
#    'Free to Play',
#    'Multiplayer',
#    'Anime',
#    'Memes',
#    'Funny',
#    'Massively Multiplayer',
#    'First-Person',
#    'Open World',
#    'Early Access',
#    'Simulation',
#    'Casual',
#    'Adventure',
#    'MMORPG',
#    'Comedy',
#    'Sandbox',
#    'Dating Sim',
#    'Action',
#    'Survival Horror',
#    'Atmospheric']},
#  '320': {'name': 'Half-Life 2: Deathmatch',
#   'rating_ratio': 9.808,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['Action',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'First-Person',
#    'Sci-fi',
#    'Physics',
#    'Competitive',
#    'Funny',
#    'Co-op',
#    'Old School',
#    'PvP',
#    'Arena Shooter',
#    'Moddable',
#    'Atmospheric',
#    'Adventure',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Violent',
#    'Mod']},
#  '272060': {'name': 'Serena',
#   'rating_ratio': 3.353,
#   'price': '0',
#   'genre': ['Adventure', 'Indie'],
#   'tags': ['Horror',
#    'Free to Play',
#    'Indie',
#    'Point & Click',
#    'Psychological Horror',
#    'Story Rich',
#    'Adventure',
#    'Dark',
#    'Short',
#    'First-Person',
#    'Mystery',
#    'Atmospheric',
#    'Multiplayer',
#    'Singleplayer',
#    'Puzzle',
#    'Walking Simulator',
#    'Co-op',
#    'Hidden Object',
#    'Exploration',
#    'Romance']},
#  '739630': {'name': 'Phasmophobia',
#   'rating_ratio': 23.033,
#   'price': '1999',
#   'genre': ['Action', 'Indie', 'Early Access'],
#   'tags': ['Horror',
#    'Online Co-Op',
#    'Multiplayer',
#    'Psychological Horror',
#    'Co-op',
#    'VR',
#    'Supernatural',
#    'First-Person',
#    'Investigation',
#    'Dark',
#    'Demons',
#    'Detective',
#    'Mystery',
#    'Thriller',
#    '3D',
#    'Early Access',
#    'Indie',
#    'Action',
#    'Tactical',
#    'Singleplayer']},
#  '990080': {'name': 'Hogwarts Legacy',
#   'rating_ratio': 9.321,
#   'price': '5999',
#   'genre': ['Action', 'Adventure', 'RPG'],
#   'tags': ['Magic',
#    'Open World',
#    'Fantasy',
#    'Singleplayer',
#    'Adventure',
#    'RPG',
#    'Character Customization',
#    'Exploration',
#    'Story Rich',
#    'Third Person',
#    'Action-Adventure',
#    'Atmospheric',
#    'Action RPG',
#    'Action',
#    'Combat',
#    'Choices Matter',
#    'Puzzle',
#    'Great Soundtrack',
#    'Dark',
#    'Family Friendly']},
#  '620': {'name': 'Portal 2',
#   'rating_ratio': 75.367,
#   'price': '999',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Platformer',
#    'Puzzle',
#    'First-Person',
#    'Dark Humor',
#    'Story Rich',
#    'Puzzle-Platformer',
#    'Funny',
#    'Female Protagonist',
#    '3D Platformer',
#    'Action-Adventure',
#    'Action',
#    'FPS',
#    'Co-op',
#    'Physics',
#    'Sci-fi',
#    'Level Editor',
#    'Science',
#    'Comedy',
#    'Atmospheric',
#    'Adventure']},
#  '227940': {'name': 'Heroes & Generals',
#   'rating_ratio': 2.084,
#   'price': '0',
#   'genre': ['Action',
#    'Free To Play',
#    'Indie',
#    'Massively Multiplayer',
#    'Strategy'],
#   'tags': ['Free to Play',
#    'World War II',
#    'FPS',
#    'Multiplayer',
#    'War',
#    'Shooter',
#    'Action',
#    'First-Person',
#    'Massively Multiplayer',
#    'Strategy',
#    'Tactical',
#    'Co-op',
#    'Historical',
#    'Open World',
#    'Simulation',
#    'Atmospheric',
#    'Adventure',
#    'Indie',
#    'Early Access',
#    'RTS']},
#  '70': {'name': 'Half-Life',
#   'rating_ratio': 27.97,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Classic',
#    "1990's",
#    'Singleplayer',
#    'Multiplayer',
#    'Sci-fi',
#    'Shooter',
#    'Action',
#    'First-Person',
#    'Aliens',
#    'Story Rich',
#    'Silent Protagonist',
#    'Atmospheric',
#    'Gore',
#    'Retro',
#    'Moddable',
#    'Adventure',
#    'Action-Adventure',
#    'Difficult',
#    'PvP']},
#  '252950': {'name': 'Rocket League',
#   'rating_ratio': 6.945,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Racing', 'Sports'],
#   'tags': ['Multiplayer',
#    'Football (Soccer)',
#    'Competitive',
#    'Sports',
#    'Racing',
#    'Team-Based',
#    'Online Co-Op',
#    'Football (American)',
#    'Fast-Paced',
#    'Co-op',
#    'Action',
#    'Funny',
#    'Great Soundtrack',
#    'Local Multiplayer',
#    'Split Screen',
#    'Local Co-Op',
#    'Singleplayer',
#    '4 Player Local',
#    'Casual',
#    'Indie']},
#  '1966720': {'name': 'Lethal Company',
#   'rating_ratio': 35.213,
#   'price': '999',
#   'genre': ['Action', 'Adventure', 'Indie', 'Early Access'],
#   'tags': ['Online Co-Op',
#    'Horror',
#    'First-Person',
#    'Co-op',
#    'Survival Horror',
#    'Exploration',
#    'Funny',
#    'Psychological Horror',
#    'Sci-fi',
#    'PvE',
#    'Atmospheric',
#    'Procedural Generation',
#    'Aliens',
#    'Time Management',
#    'Adventure',
#    'Dungeon Crawler',
#    'Action',
#    'Early Access',
#    'Action-Adventure',
#    'Perma Death']},
#  '1517290': {'name': 'Battlefield 2042',
#   'rating_ratio': 0.874,
#   'price': '5999',
#   'genre': ['Action', 'Adventure', 'Casual'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Military',
#    'War',
#    'Singleplayer',
#    'Action',
#    'First-Person',
#    'Combat',
#    'Team-Based',
#    'PvP',
#    'Futuristic',
#    'Vehicular Combat',
#    'Modern',
#    'Destruction',
#    'Physics',
#    'Cinematic',
#    'Adventure',
#    'Hero Shooter',
#    'Casual']},
#  '1240440': {'name': 'Halo Infinite',
#   'rating_ratio': 2.313,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['Free to Play',
#    'FPS',
#    'Multiplayer',
#    'Singleplayer',
#    'Shooter',
#    'Action',
#    'First-Person',
#    'Open World',
#    'Sci-fi',
#    'Co-op',
#    'PvP',
#    'Competitive',
#    'Story Rich',
#    'Space',
#    'Adventure',
#    'Aliens',
#    'Lore-Rich',
#    'Cinematic',
#    'Atmospheric',
#    'Soundtrack']},
#  '582010': {'name': 'Monster Hunter: World',
#   'rating_ratio': 7.313,
#   'price': '2999',
#   'genre': ['Action'],
#   'tags': ['Co-op',
#    'Multiplayer',
#    'Action',
#    'Open World',
#    'RPG',
#    'Character Customization',
#    'Third Person',
#    'Adventure',
#    'Fantasy',
#    'Action RPG',
#    'Difficult',
#    'Singleplayer',
#    'Exploration',
#    'Great Soundtrack',
#    'Replay Value',
#    'Atmospheric',
#    'Hack and Slash',
#    'JRPG',
#    'MMORPG',
#    'Souls-like']},
#  '240': {'name': 'Counter-Strike: Source',
#   'rating_ratio': 25.815,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Shooter',
#    'FPS',
#    'Action',
#    'Multiplayer',
#    'Team-Based',
#    'First-Person',
#    'Competitive',
#    'Tactical',
#    'PvP',
#    'e-sports',
#    'Military',
#    'War',
#    'Strategy',
#    'Moddable',
#    'Singleplayer',
#    'Difficult',
#    'Atmospheric',
#    'Survival',
#    'Simulation',
#    'Sandbox']},
#  '108600': {'name': 'Project Zomboid',
#   'rating_ratio': 16.169,
#   'price': '1999',
#   'genre': ['Indie', 'RPG', 'Simulation', 'Early Access'],
#   'tags': ['Survival',
#    'Zombies',
#    'Open World',
#    'Multiplayer',
#    'Open World Survival Craft',
#    'Sandbox',
#    'Post-apocalyptic',
#    'Co-op',
#    'Crafting',
#    'Building',
#    'Indie',
#    'Simulation',
#    'RPG',
#    'Survival Horror',
#    'Realistic',
#    'Isometric',
#    'Singleplayer',
#    '2D',
#    'Adventure',
#    'Early Access']},
#  '386360': {'name': 'SMITE',
#   'rating_ratio': 3.716,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'RPG',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'MOBA',
#    'Multiplayer',
#    'Action',
#    'Third Person',
#    'Mythology',
#    'Strategy',
#    'MMORPG',
#    'Team-Based',
#    'Nostalgia',
#    'Competitive',
#    'Anime',
#    'PvP',
#    'Co-op',
#    'e-sports',
#    'Massively Multiplayer',
#    'RPG',
#    'Adventure',
#    'Casual',
#    'Strategy RPG']},
#  '10': {'name': 'Counter-Strike',
#   'rating_ratio': 37.95,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Action',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Classic',
#    'Team-Based',
#    'First-Person',
#    'Competitive',
#    'Tactical',
#    "1990's",
#    'e-sports',
#    'PvP',
#    'Old School',
#    'Military',
#    'Strategy',
#    'Survival',
#    'Score Attack',
#    '1980s',
#    'Assassin',
#    'Nostalgia']},
#  '648800': {'name': 'Raft',
#   'rating_ratio': 14.014,
#   'price': '1999',
#   'genre': ['Adventure', 'Indie', 'Simulation'],
#   'tags': ['Survival',
#    'Multiplayer',
#    'Open World Survival Craft',
#    'Co-op',
#    'Crafting',
#    'Open World',
#    'Building',
#    'Base-Building',
#    'Online Co-Op',
#    'Adventure',
#    'Sandbox',
#    'First-Person',
#    'Singleplayer',
#    'Underwater',
#    'Simulation',
#    'Early Access',
#    'Action',
#    'Indie',
#    'Strategy',
#    'Massively Multiplayer']},
#  '1468810': {'name': '鬼谷八荒 Tale of Immortal',
#   'rating_ratio': 1.136,
#   'price': '1999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Simulation'],
#   'tags': ['Management',
#    'Singleplayer',
#    'Simulation',
#    'Mythology',
#    'Sandbox',
#    'Tactical RPG',
#    'RPG',
#    'Choose Your Own Adventure',
#    'Dating Sim',
#    'Action',
#    'Adventure',
#    'Exploration',
#    'Story Rich',
#    '2D',
#    'Hack and Slash',
#    'Action RPG',
#    'Procedural Generation',
#    'Hand-drawn',
#    'Action-Adventure',
#    'Strategy RPG']},
#  '444200': {'name': 'World of Tanks Blitz',
#   'rating_ratio': 3.687,
#   'price': '0',
#   'genre': ['Action',
#    'Massively Multiplayer',
#    'Simulation',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Tanks',
#    'Free to Play',
#    'Shooter',
#    'Action',
#    'FPS',
#    'Strategy',
#    'Multiplayer',
#    'Massively Multiplayer',
#    'PvP',
#    'Real Time Tactics',
#    'World War II',
#    'Team-Based',
#    'War',
#    'Online Co-Op',
#    'Competitive',
#    'Military',
#    'Singleplayer',
#    'Realistic',
#    '3D Platformer',
#    'Vehicular Combat']},
#  '755790': {'name': 'Ring of Elysium',
#   'rating_ratio': 2.913,
#   'price': '0',
#   'genre': ['Action', 'Free To Play', 'Massively Multiplayer'],
#   'tags': ['Free to Play',
#    'Battle Royale',
#    'Shooter',
#    'Multiplayer',
#    'Survival',
#    'FPS',
#    'Action',
#    'Massively Multiplayer',
#    'Third-Person Shooter',
#    'Early Access',
#    'Singleplayer',
#    'Open World',
#    'PvP',
#    'Co-op',
#    'Tactical',
#    '3D',
#    'Violent',
#    'Gore',
#    'MOBA',
#    'First-Person']},
#  '1174180': {'name': 'Red Dead Redemption 2',
#   'rating_ratio': 11.709,
#   'price': '1499',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Story Rich',
#    'Western',
#    'Adventure',
#    'Multiplayer',
#    'Action',
#    'Realistic',
#    'Singleplayer',
#    'Shooter',
#    'Atmospheric',
#    'Horses',
#    'Beautiful',
#    'Mature',
#    'Third-Person Shooter',
#    'Great Soundtrack',
#    'Third Person',
#    'Gore',
#    'Sandbox',
#    'First-Person',
#    'FPS']},
#  '250900': {'name': 'The Binding of Isaac: Rebirth',
#   'rating_ratio': 36.738,
#   'price': '1499',
#   'genre': ['Action'],
#   'tags': ['Action Roguelike',
#    'Rogue-like',
#    'Indie',
#    'Replay Value',
#    'Difficult',
#    'Pixel Graphics',
#    'Dungeon Crawler',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Dark',
#    '2D',
#    'Local Co-Op',
#    'Remake',
#    'Gore',
#    'Procedural Generation',
#    'Rogue-lite',
#    'Atmospheric',
#    'Co-op',
#    'Action',
#    'Horror']},
#  '550650': {'name': 'Black Squad',
#   'rating_ratio': 3.158,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['Free to Play',
#    'FPS',
#    'Shooter',
#    'Multiplayer',
#    'Action',
#    'Early Access',
#    'First-Person',
#    'Military',
#    'Singleplayer',
#    'PvP',
#    'Co-op',
#    'War',
#    'Tactical',
#    'Massively Multiplayer',
#    'Team-Based',
#    'Violent',
#    'Open World',
#    'Strategy',
#    'Gore',
#    'Adventure']},
#  '367520': {'name': 'Hollow Knight',
#   'rating_ratio': 32.769,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Indie'],
#   'tags': ['Metroidvania',
#    'Souls-like',
#    'Platformer',
#    'Great Soundtrack',
#    '2D',
#    'Difficult',
#    'Indie',
#    'Singleplayer',
#    'Atmospheric',
#    'Exploration',
#    'Adventure',
#    'Story Rich',
#    'Hand-drawn',
#    'Multiple Endings',
#    'Action',
#    'Dark Fantasy',
#    'Open World',
#    'Cute',
#    'Controller',
#    'Side Scroller']},
#  '301520': {'name': 'Robocraft',
#   'rating_ratio': 2.708,
#   'price': '0',
#   'genre': ['Action',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG',
#    'Simulation',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Robots',
#    'Building',
#    'Multiplayer',
#    'Action',
#    'Shooter',
#    'PvP',
#    'Massively Multiplayer',
#    'Sandbox',
#    'Crafting',
#    'Third-Person Shooter',
#    'Sci-fi',
#    'Strategy',
#    'Simulation',
#    'Early Access',
#    'Indie',
#    'Open World',
#    'Funny',
#    'Adventure',
#    'RPG']},
#  '239140': {'name': 'Dying Light',
#   'rating_ratio': 19.853,
#   'price': '1999',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Zombies',
#    'Survival Horror',
#    'Horror',
#    'Online Co-Op',
#    'Open World',
#    'Parkour',
#    'First-Person',
#    'Survival',
#    'Open World Survival Craft',
#    'Gore',
#    'FPS',
#    'Action',
#    'PvE',
#    'Stealth',
#    'PvP',
#    'Multiplayer',
#    'Post-apocalyptic',
#    'Story Rich',
#    'Action RPG',
#    'Hack and Slash']},
#  '477160': {'name': 'Human Fall Flat',
#   'rating_ratio': 17.804,
#   'price': '1999',
#   'genre': ['Adventure', 'Casual', 'Indie', 'Simulation'],
#   'tags': ['Co-op',
#    'Funny',
#    'Puzzle',
#    'Adventure',
#    'Physics',
#    'Sandbox',
#    'Multiplayer',
#    'Puzzle-Platformer',
#    'Action',
#    'Open World',
#    'Local Co-Op',
#    'Indie',
#    'Local Multiplayer',
#    'Comedy',
#    'Parkour',
#    'Casual',
#    'Split Screen',
#    '3D Platformer',
#    'Singleplayer',
#    'Simulation']},
#  '251570': {'name': '7 Days to Die',
#   'rating_ratio': 7.778,
#   'price': '4499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy'],
#   'tags': ['Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Open World Survival Craft',
#    'Base-Building',
#    'Voxel',
#    'Post-apocalyptic',
#    'Online Co-Op',
#    'Building',
#    'Exploration',
#    'Sandbox',
#    'FPS',
#    'Simulation',
#    'Character Customization',
#    'Tower Defense',
#    'Action',
#    'Strategy',
#    'Horror',
#    'Procedural Generation']},
#  '814380': {'name': 'Sekiro: Shadows Die Twice - GOTY Edition',
#   'rating_ratio': 20.197,
#   'price': '5999',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Souls-like',
#    'Difficult',
#    'Action',
#    'Singleplayer',
#    'Ninja',
#    'Stealth',
#    'Adventure',
#    'Third Person',
#    'Open World',
#    'Story Rich',
#    'Violent',
#    'Atmospheric',
#    'Assassin',
#    'Dark Fantasy',
#    'Hack and Slash',
#    'RPG',
#    'Gore',
#    'Great Soundtrack',
#    'Rhythm',
#    'Dark']},
#  '1222670': {'name': 'The Sims 4',
#   'rating_ratio': 6.88,
#   'price': '0',
#   'genre': ['Adventure', 'Casual', 'Simulation', 'Free To Play'],
#   'tags': ['Life Sim',
#    'Character Customization',
#    'Free to Play',
#    'Building',
#    'Romance',
#    'Simulation',
#    'Sandbox',
#    'Singleplayer',
#    'Dating Sim',
#    'Relaxing',
#    'Casual',
#    'Realistic',
#    'Funny',
#    'Family Friendly',
#    'Fantasy',
#    'Cute',
#    'Immersive Sim',
#    'Adventure',
#    'Cartoony',
#    'Nudity']},
#  '417910': {'name': 'Street Warriors Online',
#   'rating_ratio': 1.352,
#   'price': '199',
#   'genre': ['Action', 'Massively Multiplayer', 'Simulation', 'Sports'],
#   'tags': ['Fighting',
#    'Action',
#    'Multiplayer',
#    'Sports',
#    'Violent',
#    'Massively Multiplayer',
#    'Simulation',
#    'Open World',
#    'Free to Play',
#    'PvP',
#    'Early Access',
#    'Co-op',
#    'Indie',
#    'Funny',
#    'Character Customization',
#    'Singleplayer']},
#  '433850': {'name': 'Z1 Battle Royale',
#   'rating_ratio': 1.259,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Free To Play', 'Massively Multiplayer'],
#   'tags': ['Survival',
#    'Massively Multiplayer',
#    'Multiplayer',
#    'Open World',
#    'Battle Royale',
#    'PvP',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Free to Play',
#    'Third-Person Shooter',
#    'Zombies',
#    'Co-op',
#    'Early Access',
#    'Online Co-Op',
#    'Adventure',
#    'First-Person',
#    'Violent',
#    'Gore',
#    'Walking Simulator']},
#  '594650': {'name': 'Hunt: Showdown 1896',
#   'rating_ratio': 2.716,
#   'price': '2999',
#   'genre': ['Action'],
#   'tags': ['Open World',
#    'Extraction Shooter',
#    'Multiplayer',
#    'Atmospheric',
#    'Tactical',
#    'FPS',
#    'Perma Death',
#    'Western',
#    'Shooter',
#    'PvP',
#    'Horror',
#    'Online Co-Op',
#    'Survival Horror',
#    'Co-op',
#    'Difficult',
#    'Battle Royale',
#    'Team-Based',
#    'Action',
#    'Gore',
#    'Zombies']},
#  '220': {'name': 'Half-Life 2',
#   'rating_ratio': 40.699,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Sci-fi',
#    'Classic',
#    'Singleplayer',
#    'Story Rich',
#    'Shooter',
#    'First-Person',
#    'Adventure',
#    'Dystopian ',
#    'Atmospheric',
#    'Zombies',
#    'Silent Protagonist',
#    'Physics',
#    'Aliens',
#    'Great Soundtrack',
#    'Horror',
#    'Multiplayer',
#    'Puzzle',
#    'Moddable']},
#  '230410': {'name': 'Warframe',
#   'rating_ratio': 6.763,
#   'price': '0',
#   'genre': ['Action', 'RPG', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Action RPG',
#    'Looter Shooter',
#    'Third-Person Shooter',
#    'Action',
#    'RPG',
#    'Third Person',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Online Co-Op',
#    'Co-op',
#    'PvE',
#    'Singleplayer',
#    'Sci-fi',
#    'Space',
#    'Lore-Rich',
#    'Shooter',
#    'Hack and Slash',
#    'Parkour',
#    'Ninja']},
#  '219990': {'name': 'Grim Dawn',
#   'rating_ratio': 14.988,
#   'price': '2499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Action RPG',
#    'Hack and Slash',
#    'Loot',
#    'Isometric',
#    'Dark Fantasy',
#    'RPG',
#    'Dungeon Crawler',
#    'Singleplayer',
#    'Co-op',
#    'Character Customization',
#    'Dark',
#    'Multiplayer',
#    'Adventure',
#    'Fantasy',
#    'Action',
#    'Atmospheric',
#    'Post-apocalyptic',
#    'Crafting',
#    'Moddable',
#    'Choices Matter']},
#  '261550': {'name': 'Mount & Blade II: Bannerlord',
#   'rating_ratio': 7.22,
#   'price': '4999',
#   'genre': ['Action', 'Indie', 'RPG', 'Simulation', 'Strategy'],
#   'tags': ['Medieval',
#    'Strategy',
#    'Open World',
#    'RPG',
#    'War',
#    'Sandbox',
#    'Multiplayer',
#    'Singleplayer',
#    'Action',
#    'Character Customization',
#    'Simulation',
#    'Moddable',
#    'Adventure',
#    'Horses',
#    'Realistic',
#    'Third Person',
#    'Historical',
#    'First-Person',
#    'Great Soundtrack',
#    'Early Access']},
#  '8930': {'name': "Sid Meier's Civilization V",
#   'rating_ratio': 22.915,
#   'price': '2999',
#   'genre': ['Strategy'],
#   'tags': ['Turn-Based Strategy',
#    'Strategy',
#    'Turn-Based',
#    'Multiplayer',
#    'Historical',
#    '4X',
#    'Addictive',
#    'Singleplayer',
#    'Hex Grid',
#    'Grand Strategy',
#    'Replay Value',
#    'Co-op',
#    'Economy',
#    'Tactical',
#    'Diplomacy',
#    'Moddable',
#    'Simulation',
#    'Classic',
#    'Great Soundtrack',
#    'Touch-Friendly']},
#  '304050': {'name': 'Trove',
#   'rating_ratio': 4.069,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Open World',
#    'Sandbox',
#    'Pixel Graphics',
#    'Fantasy',
#    'MMORPG',
#    'Voxel',
#    'Replay Value',
#    'Family Friendly',
#    'Crafting',
#    'Procedural Generation',
#    'Multiplayer',
#    'RPG',
#    'Building',
#    'Adventure',
#    'Dungeon Crawler',
#    'Massively Multiplayer',
#    'Nostalgia',
#    'Action',
#    'Colorful']},
#  '107410': {'name': 'Arma 3',
#   'rating_ratio': 9.443,
#   'price': '2999',
#   'genre': ['Action', 'Simulation', 'Strategy'],
#   'tags': ['Military',
#    'Action',
#    'Multiplayer',
#    'Shooter',
#    'Simulation',
#    'Realistic',
#    'First-Person',
#    'Open World',
#    'Tactical',
#    'FPS',
#    'War',
#    'Co-op',
#    'Strategy',
#    'Sandbox',
#    'Singleplayer',
#    'Moddable',
#    'Combat',
#    'Online Co-Op',
#    'Team-Based',
#    'Third-Person Shooter']},
#  '377160': {'name': 'Fallout 4',
#   'rating_ratio': 4.898,
#   'price': '1999',
#   'genre': ['RPG'],
#   'tags': ['Open World',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Exploration',
#    'RPG',
#    'Adventure',
#    'Atmospheric',
#    'Shooter',
#    'First-Person',
#    'Story Rich',
#    'Action',
#    'Sci-fi',
#    'FPS',
#    'Action RPG',
#    'Sandbox',
#    'Great Soundtrack',
#    'Survival',
#    'Third Person',
#    'Third-Person Shooter',
#    'Character Customization']},
#  '532210': {'name': 'Life is Strange 2',
#   'rating_ratio': 6.249,
#   'price': '3196',
#   'genre': ['Adventure'],
#   'tags': ['Choices Matter',
#    'Story Rich',
#    'Adventure',
#    'Singleplayer',
#    'Great Soundtrack',
#    'Atmospheric',
#    'Episodic',
#    'Drama',
#    'Sexual Content',
#    'Choose Your Own Adventure',
#    'LGBTQ+',
#    'Point & Click',
#    'Third Person',
#    'Walking Simulator',
#    'Mystery',
#    'Nudity',
#    'Puzzle',
#    'Comedy',
#    'Funny',
#    'Classic']},
#  '255710': {'name': 'Cities: Skylines',
#   'rating_ratio': 13.209,
#   'price': '2999',
#   'genre': ['Simulation', 'Strategy'],
#   'tags': ['City Builder',
#    'Simulation',
#    'Building',
#    'Management',
#    'Strategy',
#    'Sandbox',
#    'Singleplayer',
#    'Moddable',
#    'Economy',
#    'Resource Management',
#    'Mod',
#    'Realistic',
#    'Replay Value',
#    'Casual',
#    'Modern',
#    'Real-Time with Pause',
#    'Family Friendly',
#    'Great Soundtrack',
#    'Funny',
#    'Action']},
#  '1326470': {'name': 'Sons Of The Forest',
#   'rating_ratio': 7.104,
#   'price': '1199',
#   'genre': ['Action', 'Adventure', 'Indie', 'Simulation'],
#   'tags': ['Survival',
#    'Open World',
#    'Multiplayer',
#    'Co-op',
#    'Survival Horror',
#    'Base-Building',
#    'Horror',
#    'Crafting',
#    'First-Person',
#    'Building',
#    'Exploration',
#    'Adventure',
#    'Singleplayer',
#    'Atmospheric',
#    'Sandbox',
#    'Action-Adventure',
#    'Action',
#    'Simulation',
#    'Immersive Sim',
#    'Early Access']},
#  '289070': {'name': 'Sid Meier’s Civilization VI',
#   'rating_ratio': 6.6,
#   'price': '599',
#   'genre': ['Strategy'],
#   'tags': ['Strategy',
#    'Turn-Based Strategy',
#    'Multiplayer',
#    'Historical',
#    'Grand Strategy',
#    'Singleplayer',
#    'Turn-Based',
#    '4X',
#    'War',
#    'City Builder',
#    'Simulation',
#    'Tactical',
#    'Management',
#    'Building',
#    'Great Soundtrack',
#    'Online Co-Op',
#    'Moddable',
#    'Co-op',
#    'Hex Grid',
#    'Atmospheric']},
#  '526870': {'name': 'Satisfactory',
#   'rating_ratio': 33.72,
#   'price': '3999',
#   'genre': ['Adventure', 'Indie', 'Simulation', 'Strategy'],
#   'tags': ['Base-Building',
#    'Automation',
#    'Open World',
#    'Multiplayer',
#    'Crafting',
#    'Co-op',
#    'Resource Management',
#    'Building',
#    'Sandbox',
#    'Exploration',
#    'Adventure',
#    'Open World Survival Craft',
#    'Survival',
#    'Simulation',
#    'First-Person',
#    'Strategy',
#    'Sci-fi',
#    'Singleplayer',
#    'Early Access',
#    'Indie']},
#  '1238810': {'name': 'Battlefield V',
#   'rating_ratio': 2.436,
#   'price': '4999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Singleplayer',
#    'World War II',
#    'Shooter',
#    'War',
#    'Military',
#    'First-Person',
#    'Massively Multiplayer',
#    'PvP',
#    'Combat',
#    'Open World',
#    'Action',
#    'Historical',
#    'Destruction',
#    'Battle Royale',
#    'Atmospheric',
#    'Violent',
#    'Sexual Content',
#    'Female Protagonist']},
#  '60': {'name': 'Ricochet',
#   'rating_ratio': 4.78,
#   'price': '499',
#   'genre': ['Action'],
#   'tags': ['Action',
#    'FPS',
#    'Multiplayer',
#    'Classic',
#    'First-Person',
#    'Sci-fi',
#    'Shooter',
#    'Space',
#    'Cyberpunk',
#    '3D',
#    'Psychological Horror',
#    'Retro',
#    'Memes',
#    'Platformer',
#    'Old School',
#    'Conspiracy',
#    'Cult Classic',
#    'Competitive',
#    'Sports',
#    'Great Soundtrack']},
#  '221100': {'name': 'DayZ',
#   'rating_ratio': 3.272,
#   'price': '4999',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer'],
#   'tags': ['Survival',
#    'Open World',
#    'Online Co-Op',
#    'Zombies',
#    'Multiplayer',
#    'Post-apocalyptic',
#    'Shooter',
#    'PvP',
#    'Massively Multiplayer',
#    'Action',
#    'FPS',
#    'Horror',
#    'Sandbox',
#    'Co-op',
#    'Adventure',
#    'Survival Horror',
#    'First-Person',
#    'Simulation',
#    'Atmospheric',
#    'Choose Your Own Adventure']},
#  '1089350': {'name': 'NBA 2K20',
#   'rating_ratio': 0.995,
#   'price': '0',
#   'genre': ['Simulation', 'Sports'],
#   'tags': ['Basketball',
#    'Sports',
#    'Simulation',
#    'Multiplayer',
#    'Singleplayer',
#    'Capitalism',
#    'Casual',
#    'Loot',
#    'Local Multiplayer',
#    'Massively Multiplayer',
#    'Character Customization',
#    'Controller',
#    'Realistic']},
#  '204360': {'name': 'Castle Crashers',
#   'rating_ratio': 24.858,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Casual', 'Indie', 'RPG'],
#   'tags': ['2D',
#    'Online Co-Op',
#    'Co-op',
#    "Beat 'em up",
#    'Hack and Slash',
#    'Funny',
#    'Adventure',
#    '4 Player Local',
#    'Local Co-Op',
#    'Multiplayer',
#    'Local Multiplayer',
#    'Action',
#    'Singleplayer',
#    'Medieval',
#    'Cartoony',
#    'Cute',
#    'Comedy',
#    'RPG',
#    'Arcade',
#    'Casual']},
#  '632360': {'name': 'Risk of Rain 2',
#   'rating_ratio': 14.289,
#   'price': '824',
#   'genre': ['Action', 'Indie'],
#   'tags': ['Third-Person Shooter',
#    'Action Roguelike',
#    'Multiplayer',
#    'Co-op',
#    'Action',
#    'Rogue-lite',
#    'Rogue-like',
#    'Looter Shooter',
#    'Loot',
#    'Online Co-Op',
#    'Shooter',
#    'Difficult',
#    'Great Soundtrack',
#    'Third Person',
#    'Indie',
#    'Survival',
#    'Singleplayer',
#    'Soundtrack',
#    'Early Access',
#    'Bullet Hell']},
#  '96000': {'name': 'The Tiny Bang Story',
#   'rating_ratio': 6.867,
#   'price': '99',
#   'genre': ['Adventure', 'Casual', 'Indie'],
#   'tags': ['Puzzle',
#    'Point & Click',
#    'Hand-drawn',
#    'Steampunk',
#    'Retro',
#    'Atmospheric',
#    '2D',
#    'Story Rich',
#    'Casual',
#    'Family Friendly',
#    'Cute',
#    'Surreal',
#    'Stylized',
#    'Adventure',
#    'Hidden Object',
#    'Singleplayer',
#    'Indie',
#    'Minigames',
#    'Logic',
#    'Relaxing']},
#  '275850': {'name': "No Man's Sky",
#   'rating_ratio': 4.879,
#   'price': '2399',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Open World Survival Craft',
#    'Space',
#    'Exploration',
#    'Sci-fi',
#    'Survival',
#    'Procedural Generation',
#    'Adventure',
#    'First-Person',
#    'Multiplayer',
#    'Sandbox',
#    'Singleplayer',
#    'Atmospheric',
#    'Crafting',
#    'Space Sim',
#    'Indie',
#    'Action',
#    'Simulation',
#    'FPS',
#    'VR']},
#  '1811260': {'name': 'EA SPORTS FIFA 23',
#   'rating_ratio': 1.32,
#   'price': '0',
#   'genre': ['Simulation', 'Sports'],
#   'tags': ['Football (Soccer)',
#    'Sports',
#    'Controller',
#    'e-sports',
#    'PvP',
#    'Management',
#    'Simulation',
#    'Team-Based',
#    'Realistic',
#    'Third Person',
#    'Immersive Sim',
#    'Multiplayer',
#    'Local Multiplayer',
#    'Local Co-Op',
#    'Co-op',
#    'Singleplayer',
#    'Online Co-Op',
#    'PvE',
#    'Free to Play',
#    'LGBTQ+']},
#  '322170': {'name': 'Geometry Dash',
#   'rating_ratio': 14.188,
#   'price': '499',
#   'genre': ['Action', 'Indie'],
#   'tags': ['Difficult',
#    'Music',
#    'Level Editor',
#    'Great Soundtrack',
#    'Precision Platformer',
#    '2D',
#    'Rhythm',
#    'Singleplayer',
#    'Colorful',
#    'Platformer',
#    'Character Customization',
#    'Indie',
#    'Arcade',
#    'Side Scroller',
#    'Family Friendly',
#    'Action',
#    'Funny',
#    'Casual',
#    'Strategy',
#    'Adventure']},
#  '1046930': {'name': 'Dota Underlords',
#   'rating_ratio': 4.634,
#   'price': '0',
#   'genre': ['Casual', 'Free To Play', 'Strategy'],
#   'tags': ['Free to Play',
#    'Strategy',
#    'Auto Battler',
#    'Casual',
#    'Multiplayer',
#    'Tactical',
#    'Chess',
#    'Turn-Based Tactics',
#    'Turn-Based',
#    'Mature',
#    'Competitive',
#    'Fantasy',
#    'Board Game',
#    'Card Game',
#    'Deckbuilding',
#    'Singleplayer',
#    'PvP',
#    'Co-op',
#    'Automation',
#    'MOBA']},
#  '49520': {'name': 'Borderlands 2',
#   'rating_ratio': 15.412,
#   'price': '499',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Loot',
#    'Shooter',
#    'Action',
#    'Multiplayer',
#    'Co-op',
#    'Looter Shooter',
#    'FPS',
#    'RPG',
#    'First-Person',
#    'Funny',
#    'Comedy',
#    'Open World',
#    'Combat',
#    'Online Co-Op',
#    'Adventure',
#    'Action RPG',
#    'Dark Humor',
#    'Singleplayer',
#    'Memes',
#    'Sci-fi']},
#  '224260': {'name': 'No More Room in Hell',
#   'rating_ratio': 8.894,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Zombies',
#    'Multiplayer',
#    'Survival',
#    'Horror',
#    'Co-op',
#    'Online Co-Op',
#    'Action',
#    'FPS',
#    'First-Person',
#    'Survival Horror',
#    'Shooter',
#    'Post-apocalyptic',
#    'Open World',
#    'Realistic',
#    'Indie',
#    'Atmospheric',
#    'Mod',
#    'Adventure',
#    'Massively Multiplayer']},
#  '489520': {'name': 'Minion Masters',
#   'rating_ratio': 8.566,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Strategy', 'Free To Play'],
# ...
#    'Singleplayer',
#    'Multiplayer',
#    'Shooter',
#    'Driving',
#    'Story Rich',
#    'Adventure',
#    'Sandbox',
#    'Mature',
#    'Great Soundtrack',
#    'Third-Person Shooter',
#    'Moddable',
#    'Atmospheric',
#    'Funny',
#    'Comedy']},
#  '1286830': {'name': 'STAR WARS: The Old Republic',
#   'rating_ratio': 8.618,
#   'price': '0',
#   'genre': ['Massively Multiplayer', 'RPG', 'Free To Play'],
#   'tags': ['Free to Play',
#    'MMORPG',
#    'Multiplayer',
#    'Character Customization',
#    'Open World',
#    'RPG',
#    'Story Rich',
#    'Choices Matter',
#    'Massively Multiplayer',
#    'Sci-fi',
#    'Adventure',
#    'Space',
#    'Action',
#    'Third Person',
#    'PvP',
#    'Atmospheric',
#    'Action RPG',
#    'Party-Based RPG',
#    'Great Soundtrack',
#    'Controller']},
#  '268500': {'name': 'XCOM 2',
#   'rating_ratio': 5.525,
#   'price': '299',
#   'genre': ['Strategy'],
#   'tags': ['Strategy',
#    'Turn-Based',
#    'Turn-Based Strategy',
#    'Tactical',
#    'Turn-Based Tactics',
#    'Aliens',
#    'Sci-fi',
#    'Character Customization',
#    'Singleplayer',
#    'Difficult',
#    'Multiplayer',
#    'RPG',
#    'Moddable',
#    'Perma Death',
#    'Futuristic',
#    'Action',
#    'Atmospheric',
#    'Great Soundtrack',
#    'Co-op',
#    'Base-Building']},
#  '500': {'name': 'Left 4 Dead',
#   'rating_ratio': 26.13,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Zombies',
#    'Co-op',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Horror',
#    'Shooter',
#    'Online Co-Op',
#    'Survival',
#    'Team-Based',
#    'First-Person',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Atmospheric',
#    'Adventure',
#    'Moddable',
#    'Tactical',
#    'Replay Value',
#    'Competitive',
#    'Female Protagonist']},
#  '8870': {'name': 'BioShock Infinite',
#   'rating_ratio': 15.22,
#   'price': '749',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Story Rich',
#    'Action',
#    'Singleplayer',
#    'Steampunk',
#    'Atmospheric',
#    'Shooter',
#    'First-Person',
#    'Beautiful',
#    'Alternate History',
#    'Adventure',
#    'Great Soundtrack',
#    'Dystopian ',
#    'Sci-fi',
#    'Time Travel',
#    'Fantasy',
#    'Gore',
#    'Linear',
#    'RPG',
#    'Immersive']},
#  '629760': {'name': 'MORDHAU',
#   'rating_ratio': 4.086,
#   'price': '2999',
#   'genre': ['Action', 'Indie'],
#   'tags': ['Medieval',
#    'Multiplayer',
#    'First-Person',
#    'Swordplay',
#    'Gore',
#    'PvP',
#    'Online Co-Op',
#    'Action',
#    'Fighting',
#    'PvE',
#    'Character Customization',
#    'Hack and Slash',
#    'Third Person',
#    'Team-Based',
#    'Realistic',
#    'Competitive',
#    'Historical',
#    'Indie',
#    'FPS',
#    'Survival']},
#  '588650': {'name': 'Dead Cells',
#   'rating_ratio': 33.398,
#   'price': '2499',
#   'genre': ['Action', 'Adventure', 'Indie'],
#   'tags': ['Adventure',
#    'Action Roguelike',
#    'Metroidvania',
#    'Pixel Graphics',
#    'Rogue-like',
#    '2D',
#    'Souls-like',
#    'Rogue-lite',
#    'Difficult',
#    'Replay Value',
#    'Hack and Slash',
#    'Platformer',
#    'Singleplayer',
#    'Roguevania',
#    'Action',
#    'Dark Fantasy',
#    'Atmospheric',
#    'Procedural Generation',
#    'Funny',
#    'Indie']},
#  '646570': {'name': 'Slay the Spire',
#   'rating_ratio': 44.784,
#   'price': '2499',
#   'genre': ['Indie', 'Strategy'],
#   'tags': ['Roguelike Deckbuilder',
#    'Card Game',
#    'Card Battler',
#    'Rogue-like',
#    'Deckbuilding',
#    'Turn-Based',
#    'Strategy',
#    'Singleplayer',
#    'Rogue-lite',
#    'Replay Value',
#    'Indie',
#    'Difficult',
#    'Dungeon Crawler',
#    'RPG',
#    'Mouse only',
#    '2D',
#    'Great Soundtrack',
#    'Procedural Generation',
#    'Fantasy',
#    'Casual']},
#  '233450': {'name': 'Prison Architect',
#   'rating_ratio': 8.192,
#   'price': '2999',
#   'genre': ['Indie', 'Simulation', 'Strategy'],
#   'tags': ['Simulation',
#    'Building',
#    'Sandbox',
#    'Base-Building',
#    'Colony Sim',
#    'Strategy',
#    'Management',
#    'City Builder',
#    '2D',
#    'Top-Down',
#    'Multiplayer',
#    'Resource Management',
#    'Economy',
#    'Singleplayer',
#    'Moddable',
#    'Capitalism',
#    'Funny',
#    'Replay Value',
#    'Indie',
#    'Casual']},
#  '109600': {'name': 'Neverwinter',
#   'rating_ratio': 3.473,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'MMORPG',
#    'RPG',
#    'Massively Multiplayer',
#    'Adventure',
#    'Multiplayer',
#    'Fantasy',
#    'Action',
#    'Open World',
#    'Character Customization',
#    'Dungeons & Dragons',
#    'Co-op',
#    'Dragons',
#    'PvP',
#    'Action RPG',
#    'PvE',
#    'Third Person',
#    'Hack and Slash',
#    'Atmospheric',
#    'Zombies']},
#  '380': {'name': 'Half-Life 2: Episode One',
#   'rating_ratio': 22.658,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Sci-fi',
#    'Singleplayer',
#    'Story Rich',
#    'First-Person',
#    'Shooter',
#    'Classic',
#    'Dystopian ',
#    'Aliens',
#    'Zombies',
#    'Adventure',
#    'Episodic',
#    'Atmospheric',
#    'Silent Protagonist',
#    'Great Soundtrack',
#    'Short',
#    'Puzzle',
#    'Cinematic',
#    'Moddable']},
#  '677620': {'name': 'Splitgate: Arena Warfare',
#   'rating_ratio': 10.883,
#   'price': '0',
#   'genre': ['Action', 'Free To Play', 'Indie'],
#   'tags': ['Free to Play',
#    'FPS',
#    'Multiplayer',
#    'Arena Shooter',
#    'Shooter',
#    'Action',
#    'Fast-Paced',
#    'First-Person',
#    'PvP',
#    'Competitive',
#    'Sci-fi',
#    'Indie',
#    'Team-Based',
#    'e-sports',
#    'Tactical',
#    'Strategy',
#    'Online Co-Op',
#    'Physics',
#    'Co-op',
#    'Violent']},
#  '1049590': {'name': 'Eternal Return: Black Survival',
#   'rating_ratio': 3.911,
#   'price': '0',
#   'genre': ['Indie', 'Strategy', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Anime',
#    'Multiplayer',
#    'MOBA',
#    'Survival',
#    'Sexual Content',
#    'PvP',
#    'Combat',
#    'Top-Down',
#    'Action',
#    'Crafting',
#    '3D',
#    'Strategy',
#    'Tactical',
#    'Character Customization',
#    'MMORPG',
#    'Indie',
#    'e-sports',
#    'Point & Click',
#    'Real Time Tactics']},
#  '1118200': {'name': 'People Playground',
#   'rating_ratio': 69.845,
#   'price': '999',
#   'genre': ['Action', 'Casual', 'Indie', 'Simulation'],
#   'tags': ['Sandbox',
#    'Gore',
#    'Physics',
#    'Blood',
#    'Moddable',
#    'Violent',
#    '2D',
#    'Singleplayer',
#    'Destruction',
#    'Simulation',
#    'Funny',
#    'Building',
#    'Pixel Graphics',
#    'Psychological Horror',
#    'Indie',
#    'Action',
#    'Casual',
#    'Comedy',
#    'Horror',
#    'Choose Your Own Adventure']},
#  '268910': {'name': 'Cuphead',
#   'rating_ratio': 26.175,
#   'price': '1999',
#   'genre': ['Action', 'Indie'],
#   'tags': ['Difficult',
#    'Cartoon',
#    'Co-op',
#    'Platformer',
#    'Great Soundtrack',
#    'Local Co-Op',
#    '2D',
#    'Hand-drawn',
#    'Multiplayer',
#    'Indie',
#    'Retro',
#    'Cartoony',
#    'Bullet Hell',
#    'Action',
#    "Shoot 'Em Up",
#    'Singleplayer',
#    'Side Scroller',
#    'Colorful',
#    'Funny',
#    'Souls-like']},
#  '397900': {'name': 'Business Tour - Board Game with Online Multiplayer',
#   'rating_ratio': 1.548,
#   'price': '0',
#   'genre': ['Adventure',
#    'Casual',
#    'Indie',
#    'Massively Multiplayer',
#    'Simulation',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Board Game',
#    'Free to Play',
#    'Multiplayer',
#    'Strategy',
#    'Casual',
#    'Massively Multiplayer',
#    'Indie',
#    'Co-op',
#    'Capitalism',
#    'Online Co-Op',
#    'Funny',
#    'Management',
#    'Family Friendly',
#    'Adventure',
#    'Singleplayer',
#    'Trading',
#    'Simulation',
#    'Tabletop',
#    'Psychological Horror',
#    'Comedy']},
#  '435150': {'name': 'Divinity: Original Sin 2 - Definitive Edition',
#   'rating_ratio': 23.006,
#   'price': '4499',
#   'genre': ['Adventure', 'RPG', 'Strategy'],
#   'tags': ['Tactical RPG',
#    'RPG',
#    'Turn-Based Strategy',
#    'Story Rich',
#    'Fantasy',
#    'Character Customization',
#    'CRPG',
#    'Exploration',
#    'Party-Based RPG',
#    'Strategy RPG',
#    'PvP',
#    'Female Protagonist',
#    'Co-op Campaign',
#    'Local Co-Op',
#    'Choices Matter',
#    'Isometric',
#    'Romance',
#    'Strategy',
#    'Moddable',
#    'Funny']},
#  '698780': {'name': 'Doki Doki Literature Club!',
#   'rating_ratio': 27.265,
#   'price': '0',
#   'genre': ['Casual', 'Free To Play', 'Indie'],
#   'tags': ['Psychological Horror',
#    'Visual Novel',
#    'Anime',
#    'Free to Play',
#    'Dating Sim',
#    'Horror',
#    'Cute',
#    'Dark',
#    'Story Rich',
#    'Romance',
#    'Singleplayer',
#    'Great Soundtrack',
#    'Gore',
#    'Violent',
#    'Indie',
#    'Sexual Content',
#    'First-Person',
#    'Memes',
#    'Casual',
#    'Adventure']},
#  '1237970': {'name': 'Titanfall 2',
#   'rating_ratio': 20.83,
#   'price': '2999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Mechs',
#    'Multiplayer',
#    'Shooter',
#    'Singleplayer',
#    'Action',
#    'Parkour',
#    'Sci-fi',
#    'First-Person',
#    'Futuristic',
#    'PvP',
#    'Combat',
#    'Military',
#    'Fast-Paced',
#    'Team-Based',
#    'Time Travel',
#    'Hero Shooter',
#    'Violent',
#    'Co-op',
#    'Gore']},
#  '863550': {'name': 'HITMAN 2',
#   'rating_ratio': 10.091,
#   'price': '0',
#   'genre': ['Action'],
#   'tags': ['Stealth',
#    'Assassin',
#    'Action',
#    'Singleplayer',
#    'Third Person',
#    'Multiplayer',
#    'Violent',
#    'Open World',
#    'Sandbox',
#    'Strategy',
#    'Puzzle',
#    'Gore',
#    'Shooter',
#    'Atmospheric',
#    'Third-Person Shooter',
#    'Co-op',
#    'Funny',
#    'Online Co-Op',
#    'Great Soundtrack',
#    'Nudity']},
#  '273110': {'name': 'Counter-Strike Nexon: Studio',
#   'rating_ratio': 1.981,
#   'price': '0',
#   'genre': ['Action',
#    'Casual',
#    'Indie',
#    'Massively Multiplayer',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'FPS',
#    'Zombies',
#    'Sandbox',
#    'PvE',
#    'PvP',
#    'Multiplayer',
#    'Shooter',
#    'Horror',
#    'Action',
#    'Co-op',
#    'First-Person',
#    'Survival Horror',
#    'Online Co-Op',
#    'Gore',
#    'Funny',
#    'Mod',
#    '3D',
#    'Dark',
#    'Singleplayer']},
#  '555570': {'name': 'Infestation: The New Z',
#   'rating_ratio': 1.164,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Massively Multiplayer', 'RPG', 'Free To Play'],
#   'tags': ['Zombies',
#    'Free to Play',
#    'Survival',
#    'Multiplayer',
#    'Open World',
#    'Massively Multiplayer',
#    'FPS',
#    'Shooter',
#    'Action',
#    'PvP',
#    'Co-op',
#    'Survival Horror',
#    'RPG',
#    'Adventure',
#    'Violent',
#    'Horror',
#    'Third-Person Shooter',
#    'PvE',
#    'Indie',
#    'Walking Simulator']},
#  '868270': {'name': 'The Cycle',
#   'rating_ratio': 1.739,
#   'price': '0',
#   'genre': ['Action', 'Free To Play', 'Massively Multiplayer'],
#   'tags': ['Extraction Shooter',
#    'Survival',
#    'Loot',
#    'Free to Play',
#    'Multiplayer',
#    'Crafting',
#    'Looter Shooter',
#    'Shooter',
#    'Tactical',
#    'PvP',
#    'First-Person',
#    'FPS',
#    'Exploration',
#    'PvE',
#    'Sci-fi',
#    'Aliens',
#    'Online Co-Op',
#    'Competitive',
#    'Adventure',
#    'Battle Royale']},
#  '1593500': {'name': 'God of War',
#   'rating_ratio': 24.173,
#   'price': '4999',
#   'genre': ['Action', 'Adventure', 'RPG'],
#   'tags': ['Action',
#    'Singleplayer',
#    'Story Rich',
#    'Adventure',
#    'Mythology',
#    'Combat',
#    'Third Person',
#    'RPG',
#    'Hack and Slash',
#    'Violent',
#    'Open World',
#    'Fantasy',
#    'Exploration',
#    'Atmospheric',
#    'Gore',
#    'Action RPG',
#    'Souls-like',
#    'Emotional',
#    '3D',
#    'PvE']},
#  '782330': {'name': 'DOOM Eternal',
#   'rating_ratio': 10.284,
#   'price': '3999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Gore',
#    'Great Soundtrack',
#    'Fast-Paced',
#    'Violent',
#    'Demons',
#    'Shooter',
#    'First-Person',
#    'Singleplayer',
#    'Blood',
#    'Multiplayer',
#    'Sci-fi',
#    'Post-apocalyptic',
#    'Mature',
#    'Atmospheric',
#    'Story Rich',
#    'Difficult',
#    'Adventure',
#    'Horror']},
#  '360': {'name': 'Half-Life Deathmatch: Source',
#   'rating_ratio': 2.949,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Action',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Sci-fi',
#    'First-Person',
#    'Classic',
#    'Remake',
#    'Violent',
#    'Adventure',
#    'Competitive',
#    'Fast-Paced',
#    'Singleplayer',
#    'Atmospheric',
#    'Horror',
#    'Gore',
#    'Great Soundtrack',
#    'Retro',
#    'Arena Shooter']},
#  '2195250': {'name': 'EA SPORTS FC 24',
#   'rating_ratio': 1.361,
#   'price': '6999',
#   'genre': ['Simulation', 'Sports'],
#   'tags': ['Football (Soccer)',
#    'Sports',
#    'Controller',
#    'Multiplayer',
#    'PvP',
#    'e-sports',
#    'Competitive',
#    'PvE',
#    'Local Multiplayer',
#    '3D',
#    'Simulation',
#    'Online Co-Op',
#    'Singleplayer',
#    'Local Co-Op',
#    'Realistic',
#    'Co-op',
#    'Family Friendly',
#    'Action',
#    'First-Person',
#    'Early Access']},
#  '391540': {'name': 'Undertale',
#   'rating_ratio': 29.452,
#   'price': '999',
#   'genre': ['Indie', 'RPG'],
#   'tags': ['Great Soundtrack',
#    'Story Rich',
#    'Choices Matter',
#    'Multiple Endings',
#    'Pixel Graphics',
#    'Funny',
#    'RPG',
#    'Singleplayer',
#    'Indie',
#    'Comedy',
#    '2D',
#    'Replay Value',
#    'Bullet Hell',
#    'Cute',
#    'Memes',
#    'Retro',
#    'Dark',
#    'Psychological Horror',
#    'Dating Sim',
#    'Horror']},
#  '294100': {'name': 'RimWorld',
#   'rating_ratio': 48.331,
#   'price': '2799',
#   'genre': ['Indie', 'Simulation', 'Strategy'],
#   'tags': ['Colony Sim',
#    'Base-Building',
#    'Survival',
#    'Strategy',
#    'Sandbox',
#    'Management',
#    'Building',
#    'Simulation',
#    'Singleplayer',
#    'Moddable',
#    'City Builder',
#    'Open World',
#    'Procedural Generation',
#    '2D',
#    'Sci-fi',
#    'Indie',
#    'Space',
#    'Tactical RPG',
#    'Cartoony',
#    'Western']},
#  '548430': {'name': 'Deep Rock Galactic',
#   'rating_ratio': 35.521,
#   'price': '2999',
#   'genre': ['Action'],
#   'tags': ['Dwarf',
#    'Co-op',
#    'PvE',
#    'FPS',
#    'Procedural Generation',
#    'Class-Based',
#    'Shooter',
#    'Exploration',
#    'First-Person',
#    'Loot',
#    'Sci-fi',
#    'Space',
#    'Action',
#    'Atmospheric',
#    'Looter Shooter',
#    'Combat',
#    'Survival',
#    'Horror',
#    'Dark',
#    'Action Roguelike']},
#  '223470': {'name': 'POSTAL 2',
#   'rating_ratio': 30.629,
#   'price': '999',
#   'genre': ['Action', 'Adventure', 'Indie'],
#   'tags': ['Violent',
#    'Dark Humor',
#    'Open World',
#    'Mature',
#    'First-Person',
#    'Funny',
#    'Comedy',
#    'Sandbox',
#    'Moddable',
#    'Third Person',
#    'Gore',
#    'FPS',
#    'Action',
#    'Dark Comedy',
#    'Multiplayer',
#    'Singleplayer',
#    'Shooter',
#    'Classic',
#    'Adventure',
#    'Satire']},
#  '766570': {'name': 'Russian Fishing 4',
#   'rating_ratio': 1.126,
#   'price': '0',
#   'genre': ['Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'RPG',
#    'Simulation',
#    'Sports',
#    'Free To Play'],
#   'tags': ['Fishing',
#    'Free to Play',
#    'Multiplayer',
#    'Simulation',
#    'Nature',
#    'Realistic',
#    'Relaxing',
#    'Crafting',
#    'First-Person',
#    'Immersive Sim',
#    'Sports',
#    'Atmospheric',
#    'Singleplayer',
#    'Open World',
#    'Survival',
#    'Massively Multiplayer',
#    'Casual',
#    'Adventure',
#    'RPG',
#    'Family Friendly']},
#  '241930': {'name': 'Middle-earth: Shadow of Mordor',
#   'rating_ratio': 12.184,
#   'price': '1999',
#   'genre': [''],
#   'tags': ['Open World',
#    'Action',
#    'Fantasy',
#    'Adventure',
#    'Third Person',
#    'Stealth',
#    'Singleplayer',
#    'RPG',
#    'Action RPG',
#    'Assassin',
#    'Hack and Slash',
#    'Gore',
#    'Parkour',
#    'Story Rich',
#    'Atmospheric',
#    'Dark Fantasy',
#    'Magic',
#    'Lore-Rich',
#    'Based On A Novel',
#    'Sandbox']},
#  '1332010': {'name': 'Stray',
#   'rating_ratio': 35.588,
#   'price': '2999',
#   'genre': ['Adventure', 'Indie'],
#   'tags': ['Cats',
#    'Adventure',
#    'Atmospheric',
#    'Cyberpunk',
#    'Singleplayer',
#    'Cute',
#    'Exploration',
#    'Robots',
#    'Beautiful',
#    'Puzzle',
#    'Third Person',
#    'Horror',
#    'Sci-fi',
#    'Indie',
#    'Dystopian ',
#    'Open World',
#    'Mystery',
#    'Action',
#    'Colorful',
#    'Stealth']},
#  '1551360': {'name': 'Forza Horizon 5',
#   'rating_ratio': 7.785,
#   'price': '5999',
#   'genre': ['Action', 'Adventure', 'Racing', 'Simulation', 'Sports'],
#   'tags': ['Racing',
#    'Open World',
#    'Driving',
#    'Multiplayer',
#    'Automobile Sim',
#    'Realistic',
#    'Simulation',
#    'Adventure',
#    'Arcade',
#    'Exploration',
#    'First-Person',
#    'Co-op',
#    'Sports',
#    'Online Co-Op',
#    'PvP',
#    'Atmospheric',
#    'Singleplayer',
#    'Beautiful',
#    'VR',
#    'Action']}}

# %% [markdown]
# ## Export data to CSV

# %%
csv_filename = "game_library_data.csv"

with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)

    header = ["game_id", "name", "rating_ratio", "price", "genre", "tags"]
    writer.writerow(header)

    for game_id, game_data in all_games_detailed.items():
        writer.writerow([
            game_id,
            game_data["name"],
            game_data["rating_ratio"],
            game_data["price"],
            ", ".join(game_data["genre"]),
            ", ".join(game_data["tags"])
        ])

# %% [markdown]
# # Part 2: Generate synthetic player-owned game libraries

# %% [markdown]
# ### Get unique list of genres

# %%
unique_genres = set()
for game_id, game_data in all_games_detailed.items():
    genres = game_data["genre"]
    for genre in genres:
        unique_genres.add(genre.strip())

unique_genres
# Out:
# {'',
#  'Action',
#  'Adventure',
#  'Animation & Modeling',
#  'Casual',
#  'Design & Illustration',
#  'Early Access',
#  'Free To Play',
#  'Indie',
#  'Massively Multiplayer',
#  'RPG',
#  'Racing',
#  'Simulation',
#  'Sports',
#  'Strategy',
#  'Video Production'}

# %%
remove_genres = ['Video Production', 'Early Access', 'Free To Play', 'Animation & Modeling',
    'Design & Illustration', '']

for genre in remove_genres:
    if genre in unique_genres:
        unique_genres.remove(genre)

unique_genres
# Out:
# {'Action',
#  'Adventure',
#  'Casual',
#  'Indie',
#  'Massively Multiplayer',
#  'RPG',
#  'Racing',
#  'Simulation',
#  'Sports',
#  'Strategy'}

# %% [markdown]
# ### Create genre-to-games mapping

# %%
genre_game_map = {}
for genre in unique_genres:
  genre_game_map[genre] = []

for game_id, game_data in all_games_detailed.items():
  for genre in game_data["genre"]:
    genre = genre.strip()
    if genre in genre_game_map:
      genre_game_map[genre].append((game_id, game_data["name"]))

genre_game_map
# Out:
# {'Racing': [('252950', 'Rocket League'),
#   ('284160', 'BeamNG.drive'),
#   ('244210', 'Assetto Corsa'),
#   ('1293830', 'Forza Horizon 4'),
#   ('211500', 'RaceRoom Racing Experience'),
#   ('1551360', 'Forza Horizon 5')],
#  'RPG': [('1623730', 'Palworld'),
#   ('1063730', 'New World: Aeternum'),
#   ('2358720', 'Black Myth: Wukong'),
#   ('1599340', 'Lost Ark'),
#   ('1245620', 'ELDEN RING'),
#   ('105600', 'Terraria'),
#   ('1086940', "Baldur's Gate 3"),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('1091500', 'Cyberpunk 2077'),
#   ('218620', 'PAYDAY 2'),
#   ('238960', 'Path of Exile'),
#   ('322330', "Don't Starve Together"),
#   ('899770', 'Last Epoch'),
#   ('413150', 'Stardew Valley'),
#   ('292030', 'The Witcher 3: Wild Hunt'),
#   ('990080', 'Hogwarts Legacy'),
#   ('108600', 'Project Zomboid'),
#   ('386360', 'SMITE'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('301520', 'Robocraft'),
#   ('239140', 'Dying Light'),
#   ('251570', '7 Days to Die'),
#   ('230410', 'Warframe'),
#   ('219990', 'Grim Dawn'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('304050', 'Trove'),
#   ('377160', 'Fallout 4'),
#   ('204360', 'Castle Crashers'),
#   ('49520', 'Borderlands 2'),
#   ('489520', 'Minion Masters'),
#   ('489830', 'The Elder Scrolls V: Skyrim Special Edition'),
#   ('72850', 'The Elder Scrolls V: Skyrim'),
#   ('588430', 'Fallout Shelter'),
#   ('22380', 'Fallout: New Vegas'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('1794680', 'Vampire Survivors'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('363970', 'Clicker Heroes'),
#   ('1145360', 'Hades'),
#   ('365590', 'Tom Clancy’s The Division'),
#   ('2183900', 'Warhammer 40,000: Space Marine 2'),
#   ('1286830', 'STAR WARS: The Old Republic'),
#   ('109600', 'Neverwinter'),
#   ('435150', 'Divinity: Original Sin 2 - Definitive Edition'),
#   ('555570', 'Infestation: The New Z'),
#   ('1593500', 'God of War'),
#   ('391540', 'Undertale'),
#   ('766570', 'Russian Fishing 4')],
#  'Casual': [('304930', 'Unturned'),
#   ('4000', "Garry's Mod"),
#   ('945360', 'Among Us'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('438100', 'VRChat'),
#   ('1517290', 'Battlefield 2042'),
#   ('386360', 'SMITE'),
#   ('477160', 'Human Fall Flat'),
#   ('1222670', 'The Sims 4'),
#   ('304050', 'Trove'),
#   ('204360', 'Castle Crashers'),
#   ('96000', 'The Tiny Bang Story'),
#   ('1046930', 'Dota Underlords'),
#   ('278360', 'A Story About My Uncle'),
#   ('1794680', 'Vampire Survivors'),
#   ('363970', 'Clicker Heroes'),
#   ('225840', 'Sven Co-op'),
#   ('238460', 'BattleBlock Theater'),
#   ('308600', 'Gene Shift Auto'),
#   ('427520', 'Factorio'),
#   ('1118200', 'People Playground'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('698780', 'Doki Doki Literature Club!'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('766570', 'Russian Fishing 4')],
#  'Indie': [('1623730', 'Palworld'),
#   ('304930', 'Unturned'),
#   ('105600', 'Terraria'),
#   ('291550', 'Brawlhalla'),
#   ('4000', "Garry's Mod"),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('238960', 'Path of Exile'),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('899770', 'Last Epoch'),
#   ('413150', 'Stardew Valley'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('227300', 'Euro Truck Simulator 2'),
#   ('272060', 'Serena'),
#   ('739630', 'Phasmophobia'),
#   ('227940', 'Heroes & Generals'),
#   ('252950', 'Rocket League'),
#   ('1966720', 'Lethal Company'),
#   ('108600', 'Project Zomboid'),
#   ('648800', 'Raft'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('367520', 'Hollow Knight'),
#   ('301520', 'Robocraft'),
#   ('477160', 'Human Fall Flat'),
#   ('251570', '7 Days to Die'),
#   ('219990', 'Grim Dawn'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('1326470', 'Sons Of The Forest'),
#   ('526870', 'Satisfactory'),
#   ('204360', 'Castle Crashers'),
#   ('632360', 'Risk of Rain 2'),
#   ('96000', 'The Tiny Bang Story'),
#   ('322170', 'Geometry Dash'),
#   ('224260', 'No More Room in Hell'),
#   ('489520', 'Minion Masters'),
#   ('466240', 'Deceit'),
#   ('370910', 'Kathy Rain'),
#   ('278360', 'A Story About My Uncle'),
#   ('275390', 'Guacamelee! Super Turbo Championship Edition'),
#   ('2881650', 'Content Warning'),
#   ('387990', 'Scrap Mechanic'),
#   ('219640', 'Chivalry: Medieval Warfare'),
#   ('244210', 'Assetto Corsa'),
#   ('1794680', 'Vampire Survivors'),
#   ('363970', 'Clicker Heroes'),
#   ('225840', 'Sven Co-op'),
#   ('1145360', 'Hades'),
#   ('1229490', 'ULTRAKILL'),
#   ('238460', 'BattleBlock Theater'),
#   ('308600', 'Gene Shift Auto'),
#   ('427520', 'Factorio'),
#   ('629760', 'MORDHAU'),
#   ('588650', 'Dead Cells'),
#   ('646570', 'Slay the Spire'),
#   ('233450', 'Prison Architect'),
#   ('677620', 'Splitgate: Arena Warfare'),
#   ('1049590', 'Eternal Return: Black Survival'),
#   ('1118200', 'People Playground'),
#   ('268910', 'Cuphead'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('698780', 'Doki Doki Literature Club!'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('555570', 'Infestation: The New Z'),
#   ('391540', 'Undertale'),
#   ('294100', 'RimWorld'),
#   ('223470', 'POSTAL 2'),
#   ('1332010', 'Stray')],
#  'Strategy': [('570', 'Dota 2'),
#   ('1086940', "Baldur's Gate 3"),
#   ('322330', "Don't Starve Together"),
#   ('444090', 'Paladins'),
#   ('552990', 'World of Warships'),
#   ('227940', 'Heroes & Generals'),
#   ('386360', 'SMITE'),
#   ('444200', 'World of Tanks Blitz'),
#   ('251570', '7 Days to Die'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('8930', "Sid Meier's Civilization V"),
#   ('107410', 'Arma 3'),
#   ('255710', 'Cities: Skylines'),
#   ('289070', 'Sid Meier’s Civilization VI'),
#   ('526870', 'Satisfactory'),
#   ('1046930', 'Dota Underlords'),
#   ('489520', 'Minion Masters'),
#   ('394360', 'Hearts of Iron IV'),
#   ('582660', 'Black Desert'),
#   ('363970', 'Clicker Heroes'),
#   ('236850', 'Europa Universalis IV'),
#   ('594570', 'Total War: WARHAMMER II'),
#   ('231430', 'Company of Heroes 2'),
#   ('427520', 'Factorio'),
#   ('268500', 'XCOM 2'),
#   ('646570', 'Slay the Spire'),
#   ('233450', 'Prison Architect'),
#   ('1049590', 'Eternal Return: Black Survival'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('435150', 'Divinity: Original Sin 2 - Definitive Edition'),
#   ('294100', 'RimWorld')],
#  'Adventure': [('578080', 'PUBG: BATTLEGROUNDS'),
#   ('1623730', 'Palworld'),
#   ('1172470', 'Apex Legends'),
#   ('1063730', 'New World: Aeternum'),
#   ('2358720', 'Black Myth: Wukong'),
#   ('271590', 'Grand Theft Auto V Legacy'),
#   ('1599340', 'Lost Ark'),
#   ('304930', 'Unturned'),
#   ('105600', 'Terraria'),
#   ('1086940', "Baldur's Gate 3"),
#   ('1085660', 'Destiny 2'),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('901583', 'Grand Theft Auto IV: Complete Edition'),
#   ('238960', 'Path of Exile'),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('1203220', 'NARAKA: BLADEPOINT'),
#   ('899770', 'Last Epoch'),
#   ('444090', 'Paladins'),
#   ('438100', 'VRChat'),
#   ('272060', 'Serena'),
#   ('990080', 'Hogwarts Legacy'),
#   ('620', 'Portal 2'),
#   ('1966720', 'Lethal Company'),
#   ('1517290', 'Battlefield 2042'),
#   ('386360', 'SMITE'),
#   ('648800', 'Raft'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('1174180', 'Red Dead Redemption 2'),
#   ('367520', 'Hollow Knight'),
#   ('477160', 'Human Fall Flat'),
#   ('251570', '7 Days to Die'),
#   ('814380', 'Sekiro: Shadows Die Twice - GOTY Edition'),
#   ('1222670', 'The Sims 4'),
#   ('433850', 'Z1 Battle Royale'),
#   ('219990', 'Grim Dawn'),
#   ('304050', 'Trove'),
#   ('532210', 'Life is Strange 2'),
#   ('1326470', 'Sons Of The Forest'),
#   ('526870', 'Satisfactory'),
#   ('221100', 'DayZ'),
#   ('204360', 'Castle Crashers'),
#   ('96000', 'The Tiny Bang Story'),
#   ('275850', "No Man's Sky"),
#   ('489520', 'Minion Masters'),
#   ('370910', 'Kathy Rain'),
#   ('278360', 'A Story About My Uncle'),
#   ('275390', 'Guacamelee! Super Turbo Championship Edition'),
#   ('311210', 'Call of Duty: Black Ops III'),
#   ('1172620', 'Sea of Thieves: 2025 Edition'),
#   ('2050650', 'Resident Evil 4'),
#   ('203160', 'Tomb Raider'),
#   ('1426210', 'It Takes Two'),
#   ('2881650', 'Content Warning'),
#   ('387990', 'Scrap Mechanic'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('518790', 'theHunter: Call of the Wild'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('363970', 'Clicker Heroes'),
#   ('253710', 'theHunter Classic'),
#   ('12210', 'Grand Theft Auto IV: The Complete Edition'),
#   ('319630', 'Life is Strange - Episode 1'),
#   ('365590', 'Tom Clancy’s The Division'),
#   ('2183900', 'Warhammer 40,000: Space Marine 2'),
#   ('238460', 'BattleBlock Theater'),
#   ('242050', 'Assassin’s Creed IV Black Flag'),
#   ('588650', 'Dead Cells'),
#   ('109600', 'Neverwinter'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('435150', 'Divinity: Original Sin 2 - Definitive Edition'),
#   ('1593500', 'God of War'),
#   ('223470', 'POSTAL 2'),
#   ('766570', 'Russian Fishing 4'),
#   ('1332010', 'Stray'),
#   ('1551360', 'Forza Horizon 5')],
#  'Sports': [('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('438100', 'VRChat'),
#   ('252950', 'Rocket League'),
#   ('417910', 'Street Warriors Online'),
#   ('1089350', 'NBA 2K20'),
#   ('1811260', 'EA SPORTS FIFA 23'),
#   ('518790', 'theHunter: Call of the Wild'),
#   ('244210', 'Assetto Corsa'),
#   ('253710', 'theHunter Classic'),
#   ('211500', 'RaceRoom Racing Experience'),
#   ('2195250', 'EA SPORTS FC 24'),
#   ('766570', 'Russian Fishing 4'),
#   ('1551360', 'Forza Horizon 5')],
#  'Action': [('570', 'Dota 2'),
#   ('730', 'Counter-Strike: Global Offensive'),
#   ('578080', 'PUBG: BATTLEGROUNDS'),
#   ('1623730', 'Palworld'),
#   ('1172470', 'Apex Legends'),
#   ('1063730', 'New World: Aeternum'),
#   ('2358720', 'Black Myth: Wukong'),
#   ('1938090', 'Call of Duty: Modern Warfare II'),
#   ('271590', 'Grand Theft Auto V Legacy'),
#   ('550', 'Left 4 Dead 2'),
#   ('553850', 'HELLDIVERS 2'),
#   ('1599340', 'Lost Ark'),
#   ('304930', 'Unturned'),
#   ('236390', 'War Thunder'),
#   ('1245620', 'ELDEN RING'),
#   ('105600', 'Terraria'),
#   ('440', 'Team Fortress 2'),
#   ('291550', 'Brawlhalla'),
#   ('359550', "Tom Clancy's Rainbow Six Siege"),
#   ('1085660', 'Destiny 2'),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('218620', 'PAYDAY 2'),
#   ('901583', 'Grand Theft Auto IV: Complete Edition'),
#   ('238960', 'Path of Exile'),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('1203220', 'NARAKA: BLADEPOINT'),
#   ('899770', 'Last Epoch'),
#   ('340', 'Half-Life 2: Lost Coast'),
#   ('381210', 'Dead by Daylight'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('444090', 'Paladins'),
#   ('552990', 'World of Warships'),
#   ('320', 'Half-Life 2: Deathmatch'),
#   ('739630', 'Phasmophobia'),
#   ('990080', 'Hogwarts Legacy'),
#   ('620', 'Portal 2'),
#   ('227940', 'Heroes & Generals'),
#   ('70', 'Half-Life'),
#   ('252950', 'Rocket League'),
#   ('1966720', 'Lethal Company'),
#   ('1517290', 'Battlefield 2042'),
#   ('1240440', 'Halo Infinite'),
#   ('582010', 'Monster Hunter: World'),
#   ('240', 'Counter-Strike: Source'),
#   ('386360', 'SMITE'),
#   ('10', 'Counter-Strike'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('444200', 'World of Tanks Blitz'),
#   ('755790', 'Ring of Elysium'),
#   ('1174180', 'Red Dead Redemption 2'),
#   ('250900', 'The Binding of Isaac: Rebirth'),
#   ('550650', 'Black Squad'),
#   ('367520', 'Hollow Knight'),
#   ('301520', 'Robocraft'),
#   ('239140', 'Dying Light'),
#   ('251570', '7 Days to Die'),
#   ('814380', 'Sekiro: Shadows Die Twice - GOTY Edition'),
#   ('417910', 'Street Warriors Online'),
#   ('433850', 'Z1 Battle Royale'),
#   ('594650', 'Hunt: Showdown 1896'),
#   ('220', 'Half-Life 2'),
#   ('230410', 'Warframe'),
#   ('219990', 'Grim Dawn'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('304050', 'Trove'),
#   ('107410', 'Arma 3'),
#   ('1326470', 'Sons Of The Forest'),
#   ('1238810', 'Battlefield V'),
#   ('60', 'Ricochet'),
#   ('221100', 'DayZ'),
#   ('204360', 'Castle Crashers'),
#   ('632360', 'Risk of Rain 2'),
#   ('275850', "No Man's Sky"),
#   ('322170', 'Geometry Dash'),
#   ('49520', 'Borderlands 2'),
#   ('224260', 'No More Room in Hell'),
#   ('489520', 'Minion Masters'),
#   ('80', 'Counter-Strike: Condition Zero'),
#   ('466240', 'Deceit'),
#   ('300', 'Day of Defeat: Source'),
#   ('275390', 'Guacamelee! Super Turbo Championship Edition'),
#   ('374320', 'DARK SOULS III'),
#   ('700330', 'SCP: Secret Laboratory'),
#   ('311210', 'Call of Duty: Black Ops III'),
#   ('1172620', 'Sea of Thieves: 2025 Edition'),
#   ('1407200', 'World of Tanks'),
#   ('2050650', 'Resident Evil 4'),
#   ('976730', 'Halo: The Master Chief Collection'),
#   ('203160', 'Tomb Raider'),
#   ('10180', 'Call of Duty: Modern Warfare 2 (2009)'),
#   ('883710', 'Resident Evil 2'),
#   ('218230', 'PlanetSide 2'),
#   ('333930', 'Dirty Bomb'),
#   ('22380', 'Fallout: New Vegas'),
#   ('1426210', 'It Takes Two'),
#   ('2881650', 'Content Warning'),
#   ('1446780', 'MONSTER HUNTER RISE'),
#   ('387990', 'Scrap Mechanic'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('20', 'Team Fortress Classic'),
#   ('219640', 'Chivalry: Medieval Warfare'),
#   ('30', 'Day of Defeat'),
#   ('1818750', 'MultiVersus'),
#   ('1794680', 'Vampire Survivors'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('225840', 'Sven Co-op'),
#   ('844870', 'KurtzPel'),
#   ('253710', 'theHunter Classic'),
#   ('12210', 'Grand Theft Auto IV: The Complete Edition'),
#   ('273350', 'Evolve Stage 2'),
#   ('1145360', 'Hades'),
#   ('319630', 'Life is Strange - Episode 1'),
#   ('365590', 'Tom Clancy’s The Division'),
#   ('1229490', 'ULTRAKILL'),
#   ('813820', 'Realm Royale'),
#   ('2183900', 'Warhammer 40,000: Space Marine 2'),
#   ('238460', 'BattleBlock Theater'),
#   ('308600', 'Gene Shift Auto'),
#   ('594570', 'Total War: WARHAMMER II'),
#   ('242050', 'Assassin’s Creed IV Black Flag'),
#   ('601150', 'Devil May Cry 5'),
#   ('12120', 'Grand Theft Auto: San Andreas'),
#   ('500', 'Left 4 Dead'),
#   ('8870', 'BioShock Infinite'),
#   ('629760', 'MORDHAU'),
#   ('588650', 'Dead Cells'),
#   ('109600', 'Neverwinter'),
#   ('380', 'Half-Life 2: Episode One'),
#   ('677620', 'Splitgate: Arena Warfare'),
#   ('1118200', 'People Playground'),
#   ('268910', 'Cuphead'),
#   ('1237970', 'Titanfall 2'),
#   ('863550', 'HITMAN 2'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('555570', 'Infestation: The New Z'),
#   ('868270', 'The Cycle'),
#   ('1593500', 'God of War'),
#   ('782330', 'DOOM Eternal'),
#   ('360', 'Half-Life Deathmatch: Source'),
#   ('548430', 'Deep Rock Galactic'),
#   ('223470', 'POSTAL 2'),
#   ('1551360', 'Forza Horizon 5')],
#  'Massively Multiplayer': [('578080', 'PUBG: BATTLEGROUNDS'),
#   ('1063730', 'New World: Aeternum'),
#   ('1599340', 'Lost Ark'),
#   ('236390', 'War Thunder'),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('238960', 'Path of Exile'),
#   ('1203220', 'NARAKA: BLADEPOINT'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('444090', 'Paladins'),
#   ('552990', 'World of Warships'),
#   ('438100', 'VRChat'),
#   ('227940', 'Heroes & Generals'),
#   ('386360', 'SMITE'),
#   ('444200', 'World of Tanks Blitz'),
#   ('755790', 'Ring of Elysium'),
#   ('301520', 'Robocraft'),
#   ('417910', 'Street Warriors Online'),
#   ('433850', 'Z1 Battle Royale'),
#   ('304050', 'Trove'),
#   ('221100', 'DayZ'),
#   ('1407200', 'World of Tanks'),
#   ('218230', 'PlanetSide 2'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('1286830', 'STAR WARS: The Old Republic'),
#   ('109600', 'Neverwinter'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('555570', 'Infestation: The New Z'),
#   ('868270', 'The Cycle'),
#   ('766570', 'Russian Fishing 4')],
#  'Simulation': [('236390', 'War Thunder'),
#   ('4000', "Garry's Mod"),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('413150', 'Stardew Valley'),
#   ('227300', 'Euro Truck Simulator 2'),
#   ('552990', 'World of Warships'),
#   ('438100', 'VRChat'),
#   ('108600', 'Project Zomboid'),
#   ('648800', 'Raft'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('444200', 'World of Tanks Blitz'),
#   ('301520', 'Robocraft'),
#   ('477160', 'Human Fall Flat'),
#   ('251570', '7 Days to Die'),
#   ('1222670', 'The Sims 4'),
#   ('417910', 'Street Warriors Online'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('107410', 'Arma 3'),
#   ('255710', 'Cities: Skylines'),
#   ('1326470', 'Sons Of The Forest'),
#   ('526870', 'Satisfactory'),
#   ('1089350', 'NBA 2K20'),
#   ('1811260', 'EA SPORTS FIFA 23'),
#   ('394360', 'Hearts of Iron IV'),
#   ('284160', 'BeamNG.drive'),
#   ('1407200', 'World of Tanks'),
#   ('588430', 'Fallout Shelter'),
#   ('387990', 'Scrap Mechanic'),
#   ('582660', 'Black Desert'),
#   ('518790', 'theHunter: Call of the Wild'),
#   ('244210', 'Assetto Corsa'),
#   ('363970', 'Clicker Heroes'),
#   ('236850', 'Europa Universalis IV'),
#   ('253710', 'theHunter Classic'),
#   ('211500', 'RaceRoom Racing Experience'),
#   ('427520', 'Factorio'),
#   ('233450', 'Prison Architect'),
#   ('1118200', 'People Playground'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('2195250', 'EA SPORTS FC 24'),
#   ('294100', 'RimWorld'),
#   ('766570', 'Russian Fishing 4'),
#   ('1551360', 'Forza Horizon 5')]}

# %% [markdown]
# ### Count the number of games per genre

# %%
genre_game_counts = {}
for genre, games in genre_game_map.items():
  genre_game_counts[genre] = len(games)

genre_game_counts
# Out:
# {'Racing': 6,
#  'RPG': 51,
#  'Casual': 25,
#  'Indie': 69,
#  'Strategy': 31,
#  'Adventure': 78,
#  'Sports': 13,
#  'Action': 146,
#  'Massively Multiplayer': 33,
#  'Simulation': 44}

# %% [markdown]
# ### Calculate number of players per focused genre based on above ratio

# %%
TOTAL_PLAYERS = 50000

total_genre_instances = sum(genre_game_counts.values())

num_players_per_genre = {
    genre: max(1, round((count / total_genre_instances) * TOTAL_PLAYERS))
    for genre, count in genre_game_counts.items()
}

# ensure total players is exactly 50,000
difference = TOTAL_PLAYERS - sum(num_players_per_genre.values())

# sort difference across genres
genres_sorted = sorted(genre_game_counts, key=genre_game_counts.get, reverse=True)

for i in range(abs(difference)):
    index = i % len(genres_sorted)
    num_players_per_genre[genres_sorted[index]] += (1 if difference > 0 else -1)

# ensure each genre has a positive number of players
for genre in num_players_per_genre:
    num_players_per_genre[genre] = max(1, num_players_per_genre[genre])

print("Final number of players per genre:", num_players_per_genre)
print("Total players generated:", sum(num_players_per_genre.values()))
# Out:
# Final number of players per genre: {'Racing': 605, 'RPG': 5141, 'Casual': 2520, 'Indie': 6956, 'Strategy': 3125, 'Adventure': 7863, 'Sports': 1310, 'Action': 14718, 'Massively Multiplayer': 3327, 'Simulation': 4435}
# Total players generated: 50000

# %% [markdown]
# ### Generate the synthetic dataset
# Iterate through each genre, generating a dynamic number of players with libraries focused on given genre

# %%
min_games_per_player = 8
max_games_per_player = 25
total_playtime_range = (300, 3000)  # min, max total playtime per player

synthetic_players = {}

for genre, game_list in genre_game_map.items():
    num_players = num_players_per_genre[genre]
    game_ids_in_genre = [game[0] for game in game_list if game[0] in all_games_detailed]  # make sure game exists

    for player_id in range(len(synthetic_players), len(synthetic_players) + num_players):
        synthetic_players[player_id] = {"focused_genre": genre, "games": {}}

        # calculate how many games each player will own
        num_games = random.randint(min_games_per_player, max_games_per_player)

        # ensure 70% of a player's games is in their focus genre
        num_genre_games = int(num_games * 0.7)  # 70% of games in focused genre
        num_other_games = num_games - num_genre_games

        owned_genre_games = random.sample(game_ids_in_genre, min(num_genre_games, len(game_ids_in_genre)))
        other_games = random.sample(
            [g_id for g_id in all_games_detailed.keys() if g_id not in owned_genre_games],
            min(num_other_games, len(all_games_detailed) - len(owned_genre_games))
        )

        total_playtime = random.randint(*total_playtime_range)

        genre_playtime = int(total_playtime * 0.95)  # ensure 95% of a player's playtime is in the focus genre
        other_playtime = total_playtime - genre_playtime


        # distribute playtime randomly
        genre_hours = np.random.dirichlet(np.ones(len(owned_genre_games))) * genre_playtime
        other_hours = np.random.dirichlet(np.ones(len(other_games))) * other_playtime if other_games else []

        # store player data
        for game_id, hours in zip(owned_genre_games, genre_hours):
            synthetic_players[player_id]["games"][game_id] = {**all_games_detailed[game_id], "hours": max(1, int(hours))}

        for game_id, hours in zip(other_games, other_hours):
            synthetic_players[player_id]["games"][game_id] = {**all_games_detailed[game_id], "hours": max(1, int(hours))}

# save dataset as json file
with open("synthetic_training_data.json", "w") as f:
    json.dump(synthetic_players, f, indent=4)

print("Synthetic dataset generated successfully!")
# Out:
# Synthetic dataset generated successfully!

# %% [markdown]
# ### Generate a list of owned games and played hours per player to run manual checks

# %%
filepath = "synthetic_training_data.json"

with open(filepath, 'r') as f:
    data = json.load(f)

if data:
    processed_data = {}

    # process each player's data
    for player_id, player_info in data.items():
        processed_data[player_id] = {
            "focused_genre": player_info["focused_genre"],
            "games": []
        }

        # sort games by # of hours played in descending orde)r
        sorted_games = sorted(player_info["games"].items(), key=lambda x: x[1]["hours"], reverse=True)

        for game_id, game_data in sorted_games:
            processed_data[player_id]["games"].append({
                "game_name": game_data["name"],
                "hours_played": game_data["hours"]
            })

    with open("processed_player_data.json", "w") as f:
        json.dump(processed_data, f, indent=4)

    print("Processed data saved to 'processed_player_data.json'")
# Out:
# Processed data saved to 'processed_player_data.json'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil

move_to_drive = [
    ("synthetic_training_data.json", "/content/drive/My Drive/503Nproj/game-rec/200/synthetic_training_data.json"),
    ("processed_player_data.json", "/content/drive/My Drive/503Nproj/game-rec/200/processed_player_data.json"),
    ("game_library_data.csv", "/content/drive/My Drive/503Nproj/game-rec/200/game_library_data.csv")
]

for src, dest in move_to_drive:
    shutil.copy(src, dest)
